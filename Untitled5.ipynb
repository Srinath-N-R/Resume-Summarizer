# %%
import spacy
from spacy.util import minibatch, compounding
from spacy.training import Example
import random
import warnings
from tqdm import tqdm
from itertools import chain
import numpy as np
import pandas as pd
import csv

# %% [markdown]
# Performed Named entity recognition using 2 models(Spacy's-CNN model & ELMo). Transfer learning was adopted for both cases.
#
# METHOD:
#
# • After performing EDA, I found out that words and tags are seperated by '\t' delimiters. And the lines are seperated by '\n'.
#
# • The data was pre-processed 2 times to fit 2 different model architectures.
#
# • The first model uses transfer learning on the "en_core_web_sm" model (a CNN model from the spaCy library).
#
# • The evaluvation metrics used in the spacy model are MAE, precision, recall and f1 score.
#
# • The loss was brought down to 931.53. Since this is a simple model, the metrics are not comparable to the sophisticated ELMo     model.
#
# • The second model uses transfer learning on the ELMo model. It is a well-known Bi-directional language model trained on a billion   word dataset. I have added LSTM units to the same model to tailor our NER problem.
#
# • The evaluvation metrics used in the ELMo model are MSE, precision, recall and f1 score.
#
# • The loss and the accuracy for this model are 0.0467 and 0.9871.
#
# • Clearly the ELMo model performs better due to it's complexity.
#
# • But, both the models perform well on unseen data ('test.txt').

# %% [markdown]
# SPACY'S CONVOLUTIONAL NEURAL NETWORK

# %% [markdown]
# STEP:1 FUNCTION TO LOAD DATA & DO BASIC PRE-PROCESSING

# %%
def load_data_for_spacy(file_path):
    file = open(file_path, 'r')
    training_data, entities, sentence, unique_labels = [], [], [], []
    current_annotation = None
    start =0
    end = 0
    for line in file:
        line = line.strip().split("\t")
        # lines with len > 1 are words
        if len(line) > 1:
            label = line[1]
            if(label != 'O'):
                label = line[1]
            word = line[0]
            sentence.append(word)
            start = end
            end += (len(word) + 1)
           
            if label.startswith('I-') == True: 
                entities.append(( start,end-1, label))
                              
            if label.startswith('B-') == True:
                entities.append(( start,end-1, label))
                
           
           
            if label != 'O' and label not in unique_labels:
                unique_labels.append(label)
 
        if len(line) == 1:
            if(len(entities) > 0):
                sentence = " ".join(sentence)
                training_data.append([sentence, {'entities' : entities}])
            end = 0 
            start = 0
            entities, sentence = [], []
            
    file.close()
    return training_data, unique_labels

# %%
TRAIN_DATA, LABELS = load_data_for_spacy("train.txt")
VALID_DATA = TRAIN_DATA[1150:]
TRAIN_DATA = TRAIN_DATA[:1150]

# %%
TRAIN_DATA
# Out:
# [["@paulwalk It 's the view from where I 'm living for two weeks . Empire State Building = ESB . Pretty bad storm here last evening .",
#   {'entities': [(64, 70, 'B-location'),
#     (71, 76, 'I-location'),
#     (77, 85, 'I-location'),
#     (88, 91, 'B-location')]}],
#  ['From Green Newsfeed : AHFA extends deadline for Sage Award to Nov . 5 http://tinyurl.com/24agj38',
#   {'entities': [(22, 26, 'B-group')]}],
#  ['Pxleyes Top 50 Photography Contest Pictures of August 2010 ... http://bit.ly/bgCyZ0 #photography',
#   {'entities': [(0, 7, 'B-corporation')]}],
#  ["4Dbling 's place til monday , party party party . &lt; 3",
#   {'entities': [(0, 7, 'B-person')]}],
#  ["watching the VMA pre-show again lol it was n't even a good show the first time ... so bored !",
#   {'entities': [(13, 16, 'B-creative-work')]}],
#  ["@Suzie55 whispering cause I may have had 1 too many vodka 's last night and am a lil fragile , hold me ?",
#   {'entities': [(52, 57, 'B-product')]}],
#  ["RT @midgetmegs : hate people who write drunk status'. must be having a great time if your sat writing it on facebook .....",
#   {'entities': [(108, 116, 'B-corporation')]}],
#  ["MetroPCS has the worst customer service I 've experienced in months ( trying to help someone order a phone ) #metropcs #fail",
#   {'entities': [(0, 8, 'B-corporation')]}],
#  ['Cant wait for the ravens game tomorrow .... go ray rice !!!!!!!',
#   {'entities': [(18, 24, 'B-group'),
#     (47, 50, 'B-person'),
#     (51, 55, 'I-person')]}],
#  ['I just took " When your mom makes you go live with your dad Scooter Braun , your life ..." and got : Part 7 ! Try it : http://tinyurl.com/27r2pdz',
#   {'entities': [(60, 67, 'B-person'), (68, 73, 'I-person')]}],
#  ['@SnoopDogg hey snoop my wife Cath is 30 today , any chance of a shout out to her ,',
#   {'entities': [(15, 20, 'B-person')]}],
#  ["Today I got a promotion at work , and tomorrow I 'm going home to Wisconsin for a few days . So content with life right now . :)",
#   {'entities': [(66, 75, 'B-location')]}],
#  ['TWEET ! @stjosephs Empls of the Month : Deborah L #Speech #Pathologist-Childrens Rehab and Patricia M #Referral/#Auth #Spec-#Womens #Care !',
#   {'entities': [(40, 47, 'B-person'),
#     (48, 49, 'I-person'),
#     (91, 99, 'B-person'),
#     (100, 101, 'I-person')]}],
#  ['RT @LilTwist : RT this if you want me to go back live on Ustream later tonight',
#   {'entities': [(57, 64, 'B-corporation')]}],
#  ["Really hope I can get to @glasgowfilm for Winter 's Bone - need to get on with job applications tonight then ! Trailer : http://bit.ly/bhUlum",
#   {'entities': [(42, 48, 'B-creative-work'),
#     (49, 51, 'I-creative-work'),
#     (52, 56, 'I-creative-work')]}],
#  ['Bonfire tonite . All are welcome , joe included',
#   {'entities': [(35, 38, 'B-person')]}],
#  ['@KFSH totally ! I can go a week w/o tv , phones or a computer . I get some time to myself and God . Brings peace into my life .',
#   {'entities': [(94, 97, 'B-person')]}],
#  ["i want a bath but do n't have a bath , shut up , sam 's coming tomorrow and steve and tanya will be round at 10am so go away you mean people",
#   {'entities': [(49, 52, 'B-person'),
#     (76, 81, 'B-person'),
#     (86, 91, 'B-person')]}],
#  ['What Do S.F. Rabbis Eat Before and After Yom Kippur ? We Asked Five to Enlighten Us ! via @SFoodie http://bit.ly/aQrFUz',
#   {'entities': [(8, 12, 'B-location')]}],
#  ["Not only is it #BattlestarGalactica 's 32nd Anniversary , tonite is the 3rd season premiere of #StarWars #TheCloneWars !!",
#   {'entities': [(15, 35, 'B-creative-work'),
#     (95, 104, 'B-creative-work'),
#     (105, 118, 'I-creative-work')]}],
#  ["just about off work ! going to alderwood again :) yay . hopefully we got cody 's ipod in the mail today .",
#   {'entities': [(31, 40, 'B-location'), (81, 85, 'B-product')]}],
#  ['RT @DamnTeenQuotes : I remember when i was your age , spencer from iCarly was Crazy Steve , Carly was Megan and Josh was fat . #damnteenquotes',
#   {'entities': [(54, 61, 'B-person'),
#     (67, 73, 'B-creative-work'),
#     (78, 83, 'B-person'),
#     (84, 89, 'I-person'),
#     (92, 97, 'B-person'),
#     (102, 107, 'B-person'),
#     (112, 116, 'B-person')]}],
#  ["@vogueglamGIRL Ah I know ! She is simply the best in The Sept Issue . My boyfriend 's aunt worked for Anna Wintor in NY .",
#   {'entities': [(102, 106, 'B-person'), (107, 113, 'I-person')]}],
#  ["There 's a lot of people showing off their iPhones on facebook today , so &lt; so is at such a place , it 's really not that interesting ;o )",
#   {'entities': [(43, 50, 'B-product'), (54, 62, 'B-corporation')]}],
#  ["Yo kids ! Today 's ACF Friday Large Group is at PITT University ! It 's at Cathedral of Learning G24 at 7pm ! Be sure to check it out !",
#   {'entities': [(48, 52, 'B-location'),
#     (53, 63, 'I-location'),
#     (75, 84, 'B-location'),
#     (85, 87, 'I-location'),
#     (88, 96, 'I-location'),
#     (97, 100, 'I-location')]}],
#  [':( RT @themaine Who is coming to the show tomorrow in Hawaii ?',
#   {'entities': [(54, 60, 'B-location')]}],
#  ['@Strigy got mine in bbt aintree today . Played table tennis on it in store ! V impressed . Did you get analogue controller 2 ?',
#   {'entities': [(24, 31, 'B-location')]}],
#  ['RT @Luq_Combs : Funniest thing I heard this week . Wingo tellin me and wood . " I \'m scared " #pow#pow#pow@Cowboy_Wingo',
#   {'entities': [(51, 56, 'B-person')]}],
#  ['Time Warner Cable Boycotting Epix Movie Channel Because It Did A Deal With Netflix http://dlvr.it/5RgcL',
#   {'entities': [(0, 4, 'B-corporation'),
#     (5, 11, 'I-corporation'),
#     (12, 17, 'I-corporation'),
#     (75, 82, 'B-corporation')]}],
#  ['After I pet a kitten on JFK , the owners informed me it \'s \' double-pawed \' ( polydactyl) , which is " a form of retardation in the animal kingdom "',
#   {'entities': [(24, 27, 'B-person')]}],
#  ['Soulja Boy | TheDeAndreWay . com - The DeAndre Way in stores Nov . 2 , 2010 http://t.co/woAiLlZ via @SouljaBoy',
#   {'entities': [(0, 6, 'B-person'), (7, 10, 'I-person')]}],
#  ['RT @RMBWilliams : Here in DC ! About to get some rest ! Looking forward to tonight ! Yes-sir !',
#   {'entities': [(26, 28, 'B-location')]}],
#  ["RT @twitter : #AskEv your big questions about the new Twitter . com today at 1pm PST . 'll be responding from his own account (@ev) . Make ...",
#   {'entities': [(54, 61, 'B-corporation')]}],
#  ["Lindsay Lohan allegedly failed her drug test . So not fetch . Quick , let 's all put on our shocked faces that 23 days of rehab did n't work !",
#   {'entities': [(0, 7, 'B-person'), (8, 13, 'I-person')]}],
#  ['I have a strong hunch Adam will be a story on TMZ tonight . Gulp .',
#   {'entities': [(22, 26, 'B-person'), (46, 49, 'B-creative-work')]}],
#  ['WEDNESDAY NITES WE CRANK IT UP AT VISIONS LOUNGE !!!!! 18+ NO COLLEGE ID NEEDED ! LADIES FREE B4 11PM ! VISIONS LOUNGE ( 247 1ST AVE HKY )',
#   {'entities': [(34, 41, 'B-location'),
#     (42, 48, 'I-location'),
#     (104, 111, 'B-location'),
#     (112, 118, 'I-location')]}],
#  ['RT @PLLGirls : Episodes 1-10 of Pretty Little Liars will air in the UK on October 18 !',
#   {'entities': [(32, 38, 'B-creative-work'),
#     (39, 45, 'I-creative-work'),
#     (46, 51, 'I-creative-work'),
#     (68, 70, 'B-location')]}],
#  ['@Loserface_Laura when mike lets me know , I will let you know . I mean everyone might just switch out a lot .',
#   {'entities': [(22, 26, 'B-person')]}],
#  ['If you are staying in Gainesville , come check out Costa Lounge TONIGHT ! Say you are with salsa caliente and get in ... http://fb.me/FZVzm8H9',
#   {'entities': [(22, 33, 'B-location'),
#     (51, 56, 'B-location'),
#     (57, 63, 'I-location'),
#     (91, 96, 'B-person'),
#     (97, 105, 'I-person')]}],
#  ['@jackjohnson where can I get the official set list to the show at Berkeley in Oct 6th ?!',
#   {'entities': [(66, 74, 'B-location')]}],
#  ['Check this video out -- Three Days Grace - Break ( Official Music Video ) [ HQ ] http://t.co/GOwCLQJ via @youtube',
#   {'entities': [(24, 29, 'B-group'),
#     (30, 34, 'I-group'),
#     (35, 40, 'I-group')]}],
#  ['@ohy22SD Hopefully the Force will be VERY strong with the #Padres tonight . We NEED a win . #ScoreSomeRuns',
#   {'entities': [(58, 65, 'B-group')]}],
#  ['Wow .. saw pictures of Robert .... spent 2 1/2 years with him . Broke up 4 months ago &amp; I miss when we were perfect ..',
#   {'entities': [(23, 29, 'B-person')]}],
#  ['@lofolulu RT @couponprincess : Please vote for me to be a Deal Pro in Chicago in November ! TY http://bit.ly/cgmnoX - DO WHAT @LOFOLULU SAYS !',
#   {'entities': [(70, 77, 'B-location')]}],
#  ['Shows Tonight-Local Natives @TheMusicBoxLA , Primus @ClubNokia Marina&amp;Diamonds @ElReyTheatre , Mystery Jets @TheTroubadour ( via @TheScenestar )',
#   {'entities': [(20, 27, 'B-group'),
#     (45, 51, 'B-group'),
#     (99, 106, 'B-group'),
#     (107, 111, 'I-group')]}],
#  ['@geek @borkware Somehow my iPad in Airplane mode with WiFi off has no problem connecting to internet . Time for a wipe or downgrade .',
#   {'entities': [(27, 31, 'B-product')]}],
#  ['Just listened to a 24 y/o kid from japan who won the national flat picking championship flipping amazing r/l august rush',
#   {'entities': [(35, 40, 'B-location')]}],
#  ['RT @ravenalexis Wanna meet me , @jessejane , @rileysteele , and @kayden_kross ? Come to the Body Heat signing at Hustler Hollywood Sep 23rd 8-10pm',
#   {'entities': [(3, 15, 'B-person'),
#     (32, 42, 'B-person'),
#     (45, 57, 'B-person'),
#     (64, 77, 'B-person'),
#     (92, 96, 'B-creative-work'),
#     (97, 101, 'I-creative-work'),
#     (113, 120, 'B-location'),
#     (121, 130, 'I-location')]}],
#  ['Toy story 3 tonight on the lawn !',
#   {'entities': [(0, 3, 'B-creative-work'),
#     (4, 9, 'I-creative-work'),
#     (10, 11, 'I-creative-work')]}],
#  ['My dad is laughing because in some translations Mark 14:30 says : "... Before the COCK crows ...". I\'ve never been so proud LOL',
#   {'entities': [(48, 52, 'B-person')]}],
#  ['Apparently 40 days , 1 hour , 49 mins and 36 seconds to Doha ....',
#   {'entities': [(56, 60, 'B-location')]}],
#  ['RT @GdnPolitics : RT @AlJahom : Blair : " I\'m gonna be the next Pope " Brown : " I won\'t stop you as long as you make sure it \'s my turn next "',
#   {'entities': [(32, 37, 'B-person'),
#     (64, 68, 'B-person'),
#     (71, 76, 'B-person')]}],
#  ['RT @Quotealicious : Today , I saw a guy driving a Pepsi truck , drinking a Coke . MLIA #Quotealicious',
#   {'entities': [(50, 55, 'B-corporation'), (75, 79, 'B-product')]}],
#  ['After I pet a kitten on JFK , the owners informed me it \'s \' double-pawed \' ( polydactyl) , which is " a form of retardation in the animal kingdom "',
#   {'entities': [(24, 27, 'B-person')]}],
#  ['@xXLauraJXx ino i did tweet him b4 n justthen about kenny signing his book but it was today ive already missed it :(',
#   {'entities': [(37, 45, 'B-person'), (52, 57, 'B-person')]}],
#  ["@shoeboxL Happy Birthday ! s/n what did I miss in Doc Lewis ' class today ? lol",
#   {'entities': [(50, 53, 'B-person'), (54, 59, 'I-person')]}],
#  ["We're on the tall ship Silva tonight . Still a few tickets available . Rain is gone and we're getting ready to set sail . 1030 PM we depart",
#   {'entities': [(9, 12, 'B-location'),
#     (13, 17, 'I-location'),
#     (18, 22, 'I-location'),
#     (23, 28, 'I-location')]}],
#  ['Playboy - 10 October 2010 Slovenia : Playboy - 10 October 2010 SloveniaSlovene | 138 pages | PDF | 39.45 Mb http://bit.ly/aJILb4',
#   {'entities': [(0, 7, 'B-corporation'),
#     (26, 34, 'B-location'),
#     (37, 44, 'B-corporation')]}],
#  ['RT @fresh_av8ted : Tonight ! " Sex In The City " Pt . 2 at #ZULA ! Hosted By : 30+ Beautiful Ladies ! [ PLz RT ]',
#   {'entities': [(31, 34, 'B-creative-work'),
#     (35, 37, 'I-creative-work'),
#     (38, 41, 'I-creative-work'),
#     (42, 46, 'I-creative-work')]}],
#  ['Accounts Payable Coordinator North York - $37K ( 1 year Contract)Location : Toronto , Ontario , CANADA ... http://bit.ly/aOe78A #jobs',
#   {'entities': [(29, 34, 'B-location'),
#     (35, 39, 'I-location'),
#     (76, 83, 'B-location'),
#     (86, 93, 'B-location'),
#     (96, 102, 'B-location')]}],
#  ['If you are in Belfast this weekend go to Botanic Gdns , for Taste N I , free food drink face painting etc . Should be good day out . Sat &amp; Sun',
#   {'entities': [(14, 21, 'B-location'),
#     (41, 48, 'B-location'),
#     (49, 53, 'I-location')]}],
#  ['Whats goin on ( in tally ) tonight twitter !!',
#   {'entities': [(35, 42, 'B-corporation')]}],
#  ['RT @davehodg : Pope says atheists pick &amp; choose their morals . Correct . Today I will be frowning on child abuse &amp; not having a problem wit ...',
#   {'entities': [(15, 19, 'B-person')]}],
#  ["VMAs . ( : I control my own life , Charles was never in charge !! It 's def one of THOSE days . Haha",
#   {'entities': [(35, 42, 'B-person')]}],
#  ['#blackholidays " National forget the he say she say ... what do God say day "',
#   {'entities': [(64, 67, 'B-person')]}],
#  ['Beautiful day in Chicago ! Nice to get away from the Florida heat .',
#   {'entities': [(17, 24, 'B-location'), (53, 60, 'B-location')]}],
#  ["Oscar 's new favorite pass time is running as fast as he can from one end of the house to another yelling BuhBYYYYYE",
#   {'entities': [(0, 5, 'B-person')]}],
#  ['@iDame2Please yea u c da pic 1st Presbyterian all day lol',
#   {'entities': [(29, 32, 'B-group'), (33, 45, 'I-group')]}],
#  ['Jan Brewer : Beheadings ? http://bit.ly/a2LBMP',
#   {'entities': [(0, 3, 'B-person'), (4, 10, 'I-person')]}],
#  ["A Hughie O'Donoghue painting , some great curvy pots and intricately illuminated Persian books .. time well spent in the Fitzwilliam .",
#   {'entities': [(2, 8, 'B-person'),
#     (9, 19, 'I-person'),
#     (117, 120, 'B-location'),
#     (121, 132, 'I-location')]}],
#  ['Greek Festival at St Johns before ASPEN',
#   {'entities': [(18, 20, 'B-location'),
#     (21, 26, 'I-location'),
#     (34, 39, 'B-location')]}],
#  ['If you are staying in Gainesville , come check out Costa Lounge TONIGHT ! Say you are with salsa caliente and get in ... http://fb.me/FZVzm8H9',
#   {'entities': [(22, 33, 'B-location'),
#     (51, 56, 'B-location'),
#     (57, 63, 'I-location'),
#     (91, 96, 'B-person'),
#     (97, 105, 'I-person')]}],
#  ['I think one of the coolest things to do would be to hang out with the Rza for a day .',
#   {'entities': [(66, 69, 'B-person'), (70, 73, 'I-person')]}],
#  ['Going on a &amp;#39 ;d ate&amp;#39 ; with Whitney tonight , :P . Haha .',
#   {'entities': [(42, 49, 'B-person')]}],
#  ['Katie up 6-0 after 1st', {'entities': [(0, 5, 'B-person')]}],
#  ['@skaffbm love that sonngg !! are u going to his concert when he goes to richmond ??',
#   {'entities': [(72, 80, 'B-location')]}],
#  ['Winner will be chosen Monday morning . Get your caption in the funny photo caption contest- Nadal and Novak in the tub http://ow.ly/2G3Jh',
#   {'entities': [(92, 97, 'B-person'), (102, 107, 'B-person')]}],
#  ['Called my homie at the door so she could get in Secrets free on Thursday ..... #HoodRatsNeedLoveToo',
#   {'entities': [(48, 55, 'B-location')]}],
#  ['What is everyone watching this weekend ? Twins ? Vikings ? anyone going to see Friday Night Lights ?',
#   {'entities': [(41, 46, 'B-group'),
#     (49, 56, 'B-group'),
#     (79, 85, 'B-creative-work'),
#     (86, 91, 'I-creative-work'),
#     (92, 98, 'I-creative-work')]}],
#  ['RT @JoeCienkowski : When people try to say how mean and harsh God was , remind them the true nature of God came in the person of Jesus Christ',
#   {'entities': [(62, 65, 'B-person'),
#     (103, 106, 'B-person'),
#     (129, 134, 'B-person'),
#     (135, 141, 'I-person')]}],
#  ['Looking for something to do tonight ? Samuel Savoirfaire Williams at Potbelly Lincoln Park in Chicago , IL http://bit.ly/bKMFgi',
#   {'entities': [(38, 44, 'B-person'),
#     (45, 56, 'I-person'),
#     (57, 65, 'I-person'),
#     (69, 77, 'B-location'),
#     (78, 85, 'I-location'),
#     (86, 90, 'I-location'),
#     (94, 101, 'B-location'),
#     (104, 106, 'B-location')]}],
#  ['Gotta dress up for london fashion week and party in style !',
#   {'entities': [(19, 25, 'B-location')]}],
#  ['I just took " When your mom makes you go live with your dad Scooter Braun , your life ..." and got : Part 5 ! Try it : http://tinyurl.com/3a5qeu6',
#   {'entities': [(60, 67, 'B-person'), (68, 73, 'I-person')]}],
#  ['New Post : Beyonce : I Am Yours Playlist Featured on VEVO Live Week [ Videos ] http://bit.ly/b1mqom',
#   {'entities': [(11, 18, 'B-person'), (53, 57, 'B-corporation')]}],
#  ["Pedersen : Hangeland won't be at Fulham for long http://bit.ly/aCXCNE #blackburnrovers",
#   {'entities': [(0, 8, 'B-person'),
#     (11, 20, 'B-person'),
#     (33, 39, 'B-location')]}],
#  ['The day you left us was a day we lost a loved one . But we will never leave you , Michael . All our love forever .',
#   {'entities': [(82, 89, 'B-person')]}],
#  ['Lohan faces more jail after failed drug test : Per the terms of her probation in her DUI case as laid out last mont ... http://bit.ly/cXoiO2',
#   {'entities': [(0, 5, 'B-person')]}],
#  ['had a great day courtesy of my morning that I had talking to Rashad ... :)',
#   {'entities': [(61, 67, 'B-person')]}],
#  ['No one cares .... RT @RapperBigPooh so Cudi got a problem with Wale now ? why ? when did this happen ? is this musical or personal ?',
#   {'entities': [(39, 43, 'B-person'), (63, 67, 'B-person')]}],
#  ['RT @cityofcalgary : Free swimming and golf tomorrow for @cbc Sports Day in Canada #yyc #sportsday http://ow.ly/2G4sf',
#   {'entities': [(75, 81, 'B-location')]}],
#  ['today in a nutshell ; abusing blind people , seducing teachers , chinese takeaways , gatt holly , phil collins , the skin of a goblins nose , lush',
#   {'entities': [(85, 89, 'B-person'),
#     (90, 95, 'I-person'),
#     (98, 102, 'B-person'),
#     (103, 110, 'I-person'),
#     (142, 146, 'B-corporation')]}],
#  ['Amazon U.K. Offering HTC Desire Z Unlocked October 11 : We just got official word of the HTC Desire Z earlier in Lo ... http://bit.ly/bsyz9H',
#   {'entities': [(21, 24, 'B-product'),
#     (25, 31, 'I-product'),
#     (32, 33, 'I-product'),
#     (89, 92, 'B-product'),
#     (93, 99, 'I-product'),
#     (100, 101, 'I-product')]}],
#  ["Watching The Room for like the fifth time . It 's a classic . Tommy WIseau is a genius . #theroom #tommywiseau",
#   {'entities': [(9, 12, 'B-creative-work'),
#     (13, 17, 'I-creative-work'),
#     (62, 67, 'B-person'),
#     (68, 74, 'I-person')]}],
#  ["Jessum 's Question of teh Day : who 's you favorite sidekick ? Yesterday 's results : http://yfrog.com/mmeoxj",
#   {'entities': [(0, 6, 'B-person')]}],
#  ['@GaryLuvin still hot ... But excited about tomorrow going to see Lady Gaga :)',
#   {'entities': [(65, 69, 'B-person'), (70, 74, 'I-person')]}],
#  ['Our Favorite YouTube Videos This Week : The Drama Edition : Had any epic meltdowns this week ? You know , of the cryin ... http://bit.ly/cuy0yt',
#   {'entities': [(13, 20, 'B-corporation')]}],
#  ['Wtf do i have a stupid 3hr shift tonight !! I wanna go out and have fun :( Oh well time to watch some Jersey Shore haha',
#   {'entities': [(102, 108, 'B-creative-work'),
#     (109, 114, 'I-creative-work')]}],
#  ['the current library plan is to go Monday morning . first books on shelves , then holds , then check bookstore on way home for The Replacement .',
#   {'entities': [(126, 129, 'B-product'), (130, 141, 'I-product')]}],
#  ['Ha ! RT @julie_cook : thanks port city java for the caffeine . not so sure my coworkers will be as pleased when i start shooting off emails at',
#   {'entities': [(29, 33, 'B-corporation'),
#     (34, 38, 'I-corporation'),
#     (39, 43, 'I-corporation')]}],
#  ['RT @pinkbikeralph : Working at BAR tonight . 1309 sansom st . More secrets than Copa . Shhhhh ...',
#   {'entities': [(31, 34, 'B-location')]}],
#  ['Bonfire tonite . All are welcome , joe included',
#   {'entities': [(35, 38, 'B-person')]}],
#  ['total 9 for Clark Duke RT @Naathan_B : Just watched hot tub time machine . Funny film ! Quite enjoyable ! Hmm 7.5 /10',
#   {'entities': [(12, 17, 'B-person'), (18, 22, 'I-person')]}],
#  ['Win $100 Visa card ! http://www.alimartell.com/index.php/2010/09/14/its-the-most-wonderful-time-of-the-year-and-im-about-to-make-it-100-better',
#   {'entities': [(9, 13, 'B-corporation')]}],
#  ['Is Joaquin Phoenix Our Modern Day Andy Kaufman ?: ... the bizarre events leading up to this moment , the movie could ... http://bit.ly/aUZ2on',
#   {'entities': [(3, 10, 'B-person'),
#     (11, 18, 'I-person'),
#     (34, 38, 'B-person'),
#     (39, 46, 'I-person')]}],
#  ['DUDE I CAN WATCH JENNIFERS BODY :O I KNOW WHAT IMMA BE DOING ALL WEEK xD I LOVE THESE MOVIES !',
#   {'entities': [(17, 26, 'B-creative-work'), (27, 31, 'I-creative-work')]}],
#  ['RT @InspiredRobin : We have so much time and so little to do . Strike that , reverse it . -Roald Dahl',
#   {'entities': [(90, 96, 'B-person'), (97, 101, 'I-person')]}],
#  ["RT @JAMESINREHAB : @4094jij05b it 's in England . Will tweet tomorrow if they let me ...",
#   {'entities': [(40, 47, 'B-location')]}],
#  ['@bowlerhatlover Been trying to find a copy of " Nostalgia " for years . http://hollisframpton.org.uk/',
#   {'entities': [(48, 57, 'B-product')]}],
#  ['Apparently #turningpoint has a hash-tag . And @RoundhouseLDN has a Twitter account . So with the formalities over ... see you tomorrow .',
#   {'entities': [(67, 74, 'B-corporation')]}],
#  ['Just casually stalking Cheryl AND Dermot tomorrow .... NO BIGGIE',
#   {'entities': [(23, 29, 'B-person'), (34, 40, 'B-person')]}],
#  ["@Robo_Robb I see you #FF ' ing me . :O ( Also Matt will be saying thanks when he 's at home :P )",
#   {'entities': [(46, 50, 'B-person')]}],
#  ['I just took " When your mom makes you go live with your dad Scooter Braun , your life turns ..." and got : Part 2 ! Try it : http://bit.ly/clxrMy',
#   {'entities': [(60, 67, 'B-person'), (68, 73, 'I-person')]}],
#  ["We are tied as the 5th band to compete in South 107 's Battle of the Bands next Friday for the spot to open for ... http://fb.me/IxhGnUhs",
#   {'entities': [(42, 47, 'B-corporation'), (48, 51, 'I-corporation')]}],
#  ["John Acuff joined @daveramseys team ! sweet ! I hope Dave gives him his own show one day , but i'm excited for JA and wish him all the best",
#   {'entities': [(0, 4, 'B-person'),
#     (5, 10, 'I-person'),
#     (53, 57, 'B-person'),
#     (111, 113, 'B-person')]}],
#  ['ANW : Update : TMZ Reporting Lindsay Lohan Just Failed Her Drug Test : We just congratulated Lindsay an hour ago on h ... http://bit.ly/a2lhpa',
#   {'entities': [(15, 18, 'B-corporation'),
#     (29, 36, 'B-person'),
#     (37, 42, 'I-person'),
#     (93, 100, 'B-person')]}],
#  ['Hope to see you tonight at Morgan Le Fays !! Great time :)',
#   {'entities': [(27, 33, 'B-location'),
#     (34, 36, 'I-location'),
#     (37, 41, 'I-location')]}],
#  ["#lindsaylohan US - Lindsay Lohan : Failed Drug Test Report Is &quot; Nuts &quot;: After it 's reported that she flunked a drug ... http://dlvr.it/5RfK7",
#   {'entities': [(14, 16, 'B-location'),
#     (19, 26, 'B-person'),
#     (27, 32, 'I-person')]}],
#  ['RT @LilTwist : RT this if you want me to go back live on Ustream later tonight',
#   {'entities': [(57, 64, 'B-corporation')]}],
#  ['Football game tonight !!!!! V-I-K-I-N-G-S !!!!!!!',
#   {'entities': [(28, 41, 'B-group')]}],
#  ["Is sad that she 's missing Cowboy Mouth tonight :(",
#   {'entities': [(27, 33, 'B-group'), (34, 39, 'I-group')]}],
#  ["RT @Queen_UK : Pope insists he left his cigarettes at Holyroodhouse . One 's asked the staff to have a look around . The DoE may well have p ...",
#   {'entities': [(15, 19, 'B-person'),
#     (54, 67, 'B-location'),
#     (121, 124, 'B-group')]}],
#  ['i was surprised when she sent me a request on facebook ... we hadnt taLked in a few years :(',
#   {'entities': [(46, 54, 'B-corporation')]}],
#  ['does any one kno the right address to the walmart that @Treysongz is suppose to be at tomorrow in maryland ??',
#   {'entities': [(42, 49, 'B-corporation'), (98, 106, 'B-location')]}],
#  ['\'I just got confirmed that me and Jorge will be playing 2 songs from " The Devils Art " at Words and Wine September ... http://fb.me/AyezVfH3\'',
#   {'entities': [(34, 39, 'B-person'),
#     (71, 74, 'B-creative-work'),
#     (75, 81, 'I-creative-work'),
#     (82, 85, 'I-creative-work')]}],
#  ['Playboy - 10 October 2010 Slovenia : Playboy - 10 October 2010 SloveniaSlovene | 138 pages | PDF | 39.45 Mb http://bit.ly/aJILb4',
#   {'entities': [(0, 7, 'B-corporation'),
#     (26, 34, 'B-location'),
#     (37, 44, 'B-corporation')]}],
#  ['@themayorpete I split my time now btwn SF and San Mateo',
#   {'entities': [(39, 41, 'B-location'),
#     (46, 49, 'B-location'),
#     (50, 55, 'I-location')]}],
#  ['dear youtube why does it take so long to upload a video gggrrrrr',
#   {'entities': [(5, 12, 'B-corporation')]}],
#  ['@welovepop much prefer a GA announcement that they are recording soon ..... it is really a bad time for GA fans at the moment .... do not like ..',
#   {'entities': [(25, 27, 'B-location'), (104, 106, 'B-location')]}],
#  ["Hey Listeners we're recording Sunday for episode 28 &amp; it 's a retrospective on the Halo franchise along with an ass load of other goodness !",
#   {'entities': [(87, 91, 'B-product')]}],
#  ['If I had one wish it would be to drive bugatti V for a day ! Pretty pls fix it for me jim ! Xxx',
#   {'entities': [(39, 46, 'B-product'), (47, 48, 'I-product')]}],
#  ['the group Maunalua will be playing tomorrow @wfmkahala at Noon !',
#   {'entities': [(10, 18, 'B-group')]}],
#  ['Anyone know what days/times that you can smoke hookah at the mix(cma center ) in corbin .',
#   {'entities': [(81, 87, 'B-location')]}],
#  ['Willow Smith is not 9 years old .... she got that Lil Mama/ Benjamin Button disease',
#   {'entities': [(0, 6, 'B-person'),
#     (7, 12, 'I-person'),
#     (60, 68, 'B-person'),
#     (69, 75, 'I-person')]}],
#  ['( via POPSUGAR ) Sarah Jessica Parker and Gwen Stefani Wrap Up Another Successful New York Fashion Week : New York Fa ... http://bit.ly/aMaJNB',
#   {'entities': [(17, 22, 'B-person'),
#     (23, 30, 'I-person'),
#     (31, 37, 'I-person'),
#     (42, 46, 'B-person'),
#     (47, 54, 'I-person'),
#     (106, 109, 'B-location'),
#     (110, 114, 'I-location')]}],
#  ["It 's supposed to rain in The Bay on Sunday ... well , weather.com says &quot; showers &quot;. Whatever , same thing .",
#   {'entities': [(26, 29, 'B-location'), (30, 33, 'I-location')]}],
#  ['Sony/Bud Light 3D tailgate parties on Saturday - Clemson party at http://bit.ly/cds8Pd ; Auburn party at http://bit.ly/9X1KP8 #sony3d @espn',
#   {'entities': [(49, 56, 'B-location'), (89, 95, 'B-location')]}],
#  ['about to get dress hangin wit the big sis Abby tonite',
#   {'entities': [(42, 46, 'B-person')]}],
#  ['RT @KhadijahC RT @SuchaMFGentlemn wonder when @sexinini is gon lt me put the 8==== =D on her ? &lt; lmfao wooooooow ( nini knws wsup ha u next lol )',
#   {'entities': [(118, 122, 'B-person')]}],
#  ['Niiiiice . http://www.pbs.org/wgbh/pages/frontline/ Watched The Persuaders in class today , super stupid example but super good .',
#   {'entities': [(60, 63, 'B-creative-work'), (64, 74, 'I-creative-work')]}],
#  ['@TheWon_A Crooked is in town October 7th !!',
#   {'entities': [(10, 17, 'B-group')]}],
#  ['Business Alliance will save you time and money and most importantly , match you with the right franchise . check out at http://ow.ly/2kt2M',
#   {'entities': [(0, 8, 'B-corporation'), (9, 17, 'I-corporation')]}],
#  ["Whoo who ready for some Seahawk football ? Can't wait to watch my dirtbags on sunday .",
#   {'entities': [(24, 31, 'B-group')]}],
#  ['RT @claywsyx6 : THE FOOTBALL FEVER : Ohio head coach Frank Solich says Ohio State knows they have a special team and season underway . Long ...',
#   {'entities': [(37, 41, 'B-location'),
#     (53, 58, 'B-person'),
#     (59, 65, 'I-person'),
#     (71, 75, 'B-group'),
#     (76, 81, 'I-group')]}],
#  ["&lt; 3 it RT @Djcheapshot : Tonite I m DJing at Mai Tai in Long Beach . I'm considering wearing MY TIE !! Get it ? My tie = Mai Tai ? No ? Sorry . Bye .",
#   {'entities': [(48, 51, 'B-location'),
#     (52, 55, 'I-location'),
#     (59, 63, 'B-location'),
#     (64, 69, 'I-location')]}],
#  ["RT @ContrarianDave : Here 's my story on today 's Forensic Science Comm . meeting , where Willingham probe took a remarkable turn . http://bi ...",
#   {'entities': [(90, 100, 'B-location')]}],
#  ['@tonygarcha Hurray ! Enjoy your time in Harrison .',
#   {'entities': [(40, 48, 'B-location')]}],
#  ['Theres nothing funny about testicles Cooper as you will find out in my office tomorrow . Lmfao .',
#   {'entities': [(37, 43, 'B-person')]}],
#  ['Foooooootball game toooonight . then auburn game tomorrow !!!! war damn eagle !!!',
#   {'entities': [(37, 43, 'B-location')]}],
#  ["RT @CHRIS_Daughtry : We're playing a show with KISS tomorrow . Can't say I saw that coming 5 years ago ...",
#   {'entities': [(47, 51, 'B-group')]}],
#  ['FUUCCCKKKK . I WAS SO FUCKING READY FOR MY GOD DAMN ALONE TIME , AND IT TURNS OUT FUCKING MADI HAS AN ILLNESS AND IS HOME W/DAD . GOD . DAMN .',
#   {'entities': [(90, 94, 'B-person')]}],
#  ["What it is twiggas it 's Friday in this bissh !!! What 's y'all niggas plans ???? Betta be at Elements tonight BOGO drinks all night !! Nuff Said",
#   {'entities': [(94, 102, 'B-location')]}],
#  ['Your paycheck may shrink next year , at least temporarily , if a vote on extending the Bush tax cuts slips past November . http://bit.ly/9y8fdS',
#   {'entities': [(87, 91, 'B-person')]}],
#  ['\'Was going to stay until Sunday but my " mother " has already made me mad furthermore hair appointment tomrrw and back to Kent !\'',
#   {'entities': [(122, 126, 'B-location')]}],
#  ['@lukeymoore you not playing tomorrow ? Dear me , is it just me and pete , is he trying to rape me',
#   {'entities': [(67, 71, 'B-person')]}],
#  ['RT @askyfullofstars : AstronomersWithoutBorders has a list of live #InOMN10 broadcasters for online Moon viewing Sept 18 http://is.gd/ffDFE',
#   {'entities': [(22, 47, 'B-group')]}],
#  ["@poscas I said to him ' the impression I had of early 80s NYC was if you went to Central Park after dark you'd be lucky to come out alive'...",
#   {'entities': [(58, 61, 'B-location'),
#     (81, 88, 'B-location'),
#     (89, 93, 'I-location')]}],
#  ["@TomCruise I'm from Brazil .... and I love you . You're my favorite actor ! Knight and Day is so cool ... My dream is to meet you !",
#   {'entities': [(20, 26, 'B-location'),
#     (76, 82, 'B-creative-work'),
#     (83, 86, 'I-creative-work'),
#     (87, 90, 'I-creative-work')]}],
#  ['Good Day Sunshine http://bit.ly/cK4PB8 is available to rent off season ! Great surfing , fishing , hot-tubbing ! I &lt; 3 fall in Rodanthe @OBXcom',
#   {'entities': [(0, 4, 'B-location'),
#     (5, 8, 'I-location'),
#     (9, 17, 'I-location'),
#     (130, 138, 'B-location')]}],
#  ['watching the VMAs Eminem is BeAsT and is smexy !!; )And Chelsea Handler is hilarious ! Finally got a boyfren he gave me the cutest thing today',
#   {'entities': [(18, 24, 'B-person'),
#     (56, 63, 'B-person'),
#     (64, 71, 'I-person')]}],
#  ['Don Mattingly will replace Joe Torre as LA Dodgers manager after this season',
#   {'entities': [(0, 3, 'B-person'),
#     (4, 13, 'I-person'),
#     (27, 30, 'B-person'),
#     (31, 36, 'I-person'),
#     (40, 42, 'B-group'),
#     (43, 50, 'I-group')]}],
#  ["It 's official !!! Vegas for the weekend ! Starting tonight !! #nohands",
#   {'entities': [(19, 24, 'B-location')]}],
#  ["RT @thirdday : RT @macpowell : Just landed in DC . Is anybody coming to the Awakening Festival tonight ? I'm thinking about rocking it .",
#   {'entities': [(46, 48, 'B-location')]}],
#  ['RT @KdotDeeZy : Yes we do !!! Is part 2 in the making ? RT @GOTEMSAYNBABY remember when i was on twitter violating some girl in the summer ?',
#   {'entities': [(97, 104, 'B-corporation')]}],
#  ['@sardesairajdeep I can see three kinds of reactions after Ayodhya verdict .',
#   {'entities': [(58, 65, 'B-person')]}],
#  ["@briancag &quot;' Brian .' Isn't available right now ...&quot; hahahaha that 's what I hear when I call your saynow .",
#   {'entities': [(18, 23, 'B-person')]}],
#  ['Chicago Blackhawks general manager Stan Bowman said Cristobal Huet will be gone in two weeks ... http://fan.ac/Ydv #NHL',
#   {'entities': [(0, 7, 'B-group'),
#     (8, 18, 'I-group'),
#     (35, 39, 'B-person'),
#     (40, 46, 'I-person'),
#     (52, 61, 'B-person'),
#     (62, 66, 'I-person')]}],
#  ['Kristen is MY LIFE . She made me who i am today , I was a fucker before her , she fixed me . And so did Robert .',
#   {'entities': [(0, 7, 'B-person'), (104, 110, 'B-person')]}],
#  ['Feeling really good after great week in our SF and LA offices . Glad to kick back on AMerican flight back to NYC',
#   {'entities': [(44, 46, 'B-location'),
#     (51, 53, 'B-location'),
#     (85, 93, 'B-corporation'),
#     (109, 112, 'B-location')]}],
#  ['UPDATE 1-Cricket-Gul takes six wickets as Pakistan beat England : LONDON , Sept 17 ( Reuters ) - Umar Gul took ... http://bit.ly/ckNyMG #Cricket',
#   {'entities': [(42, 50, 'B-location'),
#     (56, 63, 'B-location'),
#     (66, 72, 'B-location'),
#     (85, 92, 'B-corporation'),
#     (97, 101, 'B-person'),
#     (102, 105, 'I-person')]}],
#  ['Football game tonight :) yeeah boilers .. oh wait , we suck . haha',
#   {'entities': [(31, 38, 'B-group')]}],
#  ['No tasting today due to my being out Sick ... ugh . But next Friday we will have Mark Rowan from Novel Wines here ... http://fb.me/G2CLHL1H',
#   {'entities': [(81, 85, 'B-person'),
#     (86, 91, 'I-person'),
#     (97, 102, 'B-corporation'),
#     (103, 108, 'I-corporation')]}],
#  ["its friday . but instead of partying or doing homework . I'm going to tumblr for a bit and sleep XD",
#   {'entities': [(70, 76, 'B-corporation')]}],
#  ['@mynameisraven get on skype or ichat when you see this .',
#   {'entities': [(22, 27, 'B-corporation')]}],
#  ['RT @LilTwist : RT this if you want me to go back live on Ustream later tonight',
#   {'entities': [(57, 64, 'B-corporation')]}],
#  ['\'I just took " When your mom makes you go live with your dad Scooter Braun , your life turns ..." and got : Part 1 ! Try it : http://bit.ly/ch09f2\'',
#   {'entities': [(61, 68, 'B-person'), (69, 74, 'I-person')]}],
#  ['is there actually anything on UK tv tonight !',
#   {'entities': [(30, 32, 'B-location')]}],
#  ["i'm off to bed ! tomorrow i'll go to Nijverdal and meet @ElineEpica there , on her sweeeet16 #partyyy",
#   {'entities': [(37, 46, 'B-location')]}],
#  ['tonight at The Lodge : braised bison shortribs , kabocha squash risotto http://twitpic.com/2pdu4g',
#   {'entities': [(11, 14, 'B-location'), (15, 20, 'I-location')]}],
#  ['@darynjones imma tell you one time ! JUTHTIN BEAVERRRR !!!!',
#   {'entities': [(37, 44, 'B-person'), (45, 54, 'I-person')]}],
#  ['#cl CamelBak BPA-Free Better Bottle with Bite Valve by Camelbak 93 days in the top 100 ( 494)Buy new : $ 4.99 - $1 ... http://bit.ly/9YA597',
#   {'entities': [(4, 12, 'B-product'),
#     (13, 21, 'I-product'),
#     (22, 28, 'I-product'),
#     (29, 35, 'I-product'),
#     (36, 40, 'I-product'),
#     (41, 45, 'I-product'),
#     (46, 51, 'I-product'),
#     (55, 63, 'B-corporation')]}],
#  ['#SIUC Whats the Plan For tonight ?? Whos Goin to the BLAST',
#   {'entities': [(49, 52, 'B-location'), (53, 58, 'I-location')]}],
#  ["I ain't necessary listenin ' to the lyrics but the beat got head rockin'. &quot; It 's Gucci Time !&quot; #nodisrespect I fucks with every now &amp; then ...",
#   {'entities': [(87, 92, 'B-corporation')]}],
#  ['#sp Facebook Job-Hunting App BranchOut Raises $6 Million From Accel And Super Angels : When you want to hang out ... http://migre.me/1kO1K',
#   {'entities': [(4, 12, 'B-corporation'),
#     (29, 38, 'B-product'),
#     (62, 67, 'B-corporation')]}],
#  ["@TheTiniestVole It is . It 's getting across London that 's the killer . Still miss it , though . Lived there for 20 years .",
#   {'entities': [(45, 51, 'B-location')]}],
#  ['NEW ORLEANS ! - Tonight @damionyancy at Republic !',
#   {'entities': [(0, 3, 'B-location'),
#     (4, 11, 'I-location'),
#     (40, 48, 'B-location')]}],
#  ['CAFE NINE TONIGHT AT 11 !!',
#   {'entities': [(0, 4, 'B-location'), (5, 9, 'I-location')]}],
#  ['Good prospects for dabigatran on Monday . RT @DrJennyK : FDA Suggests #Afib Drug Okay Even Before Vote http://bit.ly/dpOphU #FDACV',
#   {'entities': [(19, 29, 'B-product'), (57, 60, 'B-group')]}],
#  ["Whomever said , &quot; M&amp;M 's melt in your mouth , not in your hand &quot; never had a 1/4 of a bag in their hand at one time #myhandismulicolored #Pretty",
#   {'entities': [(23, 30, 'B-product')]}],
#  ['@BenArch 100- Tim Bulmer had a 100% likelihood of getting his YPF detail form in this week . Punctuality .',
#   {'entities': [(14, 17, 'B-person'), (18, 24, 'I-person')]}],
#  ['\'Science and the media : 11 - 17 September : Under the headline " China needs to elaborate on plans to modernize its f ... http://bit.ly/bVaPzc\'',
#   {'entities': [(66, 71, 'B-location')]}],
#  ['estonia tomorrow with @MyiaOnFyia and the rest of our team ! ready for some good practice games ! :)',
#   {'entities': [(0, 7, 'B-location')]}],
#  ["&quot; I gotta admit , Alex sounds hot when he talks in spanish during the ' Alejandro ' Cover &quot; -via someone 's tumblr",
#   {'entities': [(23, 27, 'B-person'),
#     (77, 86, 'B-person'),
#     (118, 124, 'B-corporation')]}],
#  ["@OGOchoCinco depends what Leo 's revamped D can do to him on Sunday . Go Lions !!",
#   {'entities': [(26, 29, 'B-person'), (73, 78, 'B-group')]}],
#  ["Change of Plans on Saturday ! We'll be @ Glover Park farmers market , 9-1 in DC . Come by and try some old favorites &amp; crazy new flavors !",
#   {'entities': [(41, 47, 'B-location'),
#     (48, 52, 'I-location'),
#     (77, 79, 'B-location')]}],
#  ['California Woman Dies in Accident Hours Before DUI Class : Woman was drinking until early morning before court orde ... http://bit.ly/aiHEvj',
#   {'entities': [(0, 10, 'B-location')]}],
#  ['$$ #forex #fx : Forex Articles for the Weekend September 18lo http://www.forexcrunch.com/forex-articles-for-the-weekend-september-18lo/',
#   {'entities': [(16, 21, 'B-corporation')]}],
#  ["@divacoachdabney you made Nina 's day . Sweet surprises for you .",
#   {'entities': [(26, 30, 'B-person')]}],
#  ['@mandyjiroux Mandy when you and Miley will upgrade Miley and Mandy show ? I miss the videos .',
#   {'entities': [(13, 18, 'B-person'),
#     (32, 37, 'B-person'),
#     (51, 56, 'B-creative-work'),
#     (57, 60, 'I-creative-work'),
#     (61, 66, 'I-creative-work'),
#     (67, 71, 'I-creative-work')]}],
#  ["@planetjedward were 's John and Edward ... there Tweets make my day ... now what am i supposed to do :' ( COME BACK TO USSS &lt; 3",
#   {'entities': [(23, 27, 'B-person'), (32, 38, 'B-person')]}],
#  ['Analogy time ! Loyola Chicago : Alexei :: Philadelphia Eagles : Donovan McNabb ( even b4 the trade) . #nfl #fb',
#   {'entities': [(15, 21, 'B-location'),
#     (22, 29, 'B-location'),
#     (32, 38, 'B-person'),
#     (42, 54, 'B-group'),
#     (55, 61, 'I-group'),
#     (64, 71, 'B-person'),
#     (72, 78, 'I-person')]}],
#  ["Don't forget to come and see us at the football game tomorrow afternoon ! Go Reivers !",
#   {'entities': [(77, 84, 'B-group')]}],
#  ['RT @ItsROWEtime : Y does Pinky have a music video ? Thats 3 porn star rappers in the last month . This is y rap is doing so bad , ppl actual ...',
#   {'entities': [(25, 30, 'B-person')]}],
#  ['EVENT -- &gt; http://schmap.it/bP7bEZ - Tonight at Primal Its @Roscoedash , &amp; @DJDrama Taking Over ! TxT Names to 678-223-3699 by 6:59 pm',
#   {'entities': [(51, 57, 'B-location')]}],
#  ['Buffs FB : Giddings faces Elgin tonite @ Wildcat Stadium @ 7:30 . The Buffs will try to re-group after two straight losses . Updates on LCL',
#   {'entities': [(11, 19, 'B-location'),
#     (26, 31, 'B-location'),
#     (41, 48, 'B-location'),
#     (49, 56, 'I-location'),
#     (66, 69, 'B-group'),
#     (70, 75, 'I-group'),
#     (136, 139, 'B-corporation')]}],
#  ['EuroVPS celebrates its 6 Year Anniversary with special Promotion . Buy 1 VPS and get a second VPS FREE ! http://fb.me/FZAfqgWn',
#   {'entities': [(0, 7, 'B-corporation')]}],
#  ["@XrisLastRights yep well .. i know mcfly told me they were going to come back here when i met em ' but anyway :) so , how was your day ?",
#   {'entities': [(35, 40, 'B-person')]}],
#  ['what to do , what to do ... gross sushi for dinner but time with family from delaware , or leftover pizza and alone time to write and relax .',
#   {'entities': [(77, 85, 'B-location')]}],
#  ['RT @NAT3OH3 : VMB awards last night were super fun - we won best bossa nova act ! off to HSBC center to soundcheck for epic show tonight .. ...',
#   {'entities': [(14, 17, 'B-group'),
#     (89, 93, 'B-location'),
#     (94, 100, 'I-location')]}],
#  ["@_Flik_ awww he 's in the rocky horror show next week which means he 's gotta wear stockings an suspenders lol :P",
#   {'entities': [(26, 31, 'B-creative-work'),
#     (32, 38, 'I-creative-work'),
#     (39, 43, 'I-creative-work')]}],
#  ['Thanks to all who tuned in to my show on http://kplu.org the last two days . Ending with Herbie &amp; Freddie !',
#   {'entities': [(89, 95, 'B-person'), (102, 109, 'B-person')]}],
#  ['3 tour coaches with a police escort in Chapel Hill ... game tonight ?',
#   {'entities': [(39, 45, 'B-location'), (46, 50, 'I-location')]}],
#  ['Our Favorite YouTube Videos This Week : The Drama Edition http://dlvr.it/5RfHy',
#   {'entities': [(13, 20, 'B-corporation')]}],
#  ["Small Biz Tech Tour 2010 Launches Five City Tour MONTCLAIR N.J. ...: The all day event features America's... http://tinyurl.com/28hd9fu #fb",
#   {'entities': [(49, 58, 'B-location'), (59, 63, 'B-location')]}],
#  ['WIN FREE PAMPERS FOR A YEAR !!! And more ... http://nblo.gs/80qJu',
#   {'entities': [(9, 16, 'B-corporation')]}],
#  ['Preventing Public Health Disasters [ The Pump Handle] : Earlier this week , FDA Commissioner Margaret Hamburg present ... http://bit.ly/9i1AEg',
#   {'entities': [(76, 79, 'B-group'),
#     (93, 101, 'B-person'),
#     (102, 109, 'I-person')]}],
#  ['RT @robmoysey Eyeopener vs . Ryerson Quidditch team this Sunday at 4 p.m. Anyone know where to get cheap brooms ? #Ryerson @RUQuidditch #Rams',
#   {'entities': [(14, 23, 'B-group'),
#     (29, 36, 'B-group'),
#     (37, 46, 'I-group'),
#     (47, 51, 'I-group')]}],
#  ['RT @SonyElectronics : Sony/Bud Light 3D tailgate parties on Saturday - Clemson party at http://bit.ly/cds8Pd ; Auburn party at http://bit . ...',
#   {'entities': [(71, 78, 'B-location'), (111, 117, 'B-location')]}],
#  ['@Zerinaakers talking about as far as shooting for location its going to be on #Vh1 so by the end of the month i should know something',
#   {'entities': [(78, 82, 'B-corporation')]}],
#  ["I 've got a theory that if you give 100% all of the time , somehow things will work out in the end . -Larry Bird",
#   {'entities': [(101, 107, 'B-person'), (108, 112, 'I-person')]}],
#  ['@winashbrown If that auto URL shortening could work I might stick with SD2 for a while - that saves me 3 or 4 steps when I am tweeting links',
#   {'entities': [(71, 74, 'B-product')]}],
#  ['belles mansion 4 bday dinner . eventhough its a day early . *N*I*K*K*I*',
#   {'entities': [(0, 6, 'B-location'), (7, 14, 'I-location')]}],
#  ['Kahlua &lt; Coffee over looking the lake is just what the doctor ordered .... hope everyone has a great Friday night !',
#   {'entities': [(0, 6, 'B-product'), (12, 18, 'B-product')]}],
#  ['I just took " After getting trampled at a Justin Bieber concert , yoiu wake up and ..." and got : Part 6 :) ! Try it : http://tinyurl.com/26zeju5',
#   {'entities': [(42, 48, 'B-person'), (49, 55, 'I-person')]}],
#  ['Gotta love the bumper stickers of Fayette County : " Ever wonder if there is life after death ? Touch my truck and \'ll find out ."',
#   {'entities': [(34, 41, 'B-location'), (42, 48, 'I-location')]}],
#  ['Pick up here . Deliver on Dayton NJ tomorrow (@ Ball Metal Container )',
#   {'entities': [(26, 32, 'B-location'),
#     (33, 35, 'I-location'),
#     (48, 52, 'B-corporation'),
#     (53, 58, 'I-corporation'),
#     (59, 68, 'I-corporation')]}],
#  ['Soulja Boy | TheDeAndreWay . com - The DeAndre Way in stores Nov 2 , 2010 souljaboytellem-iga.ning.com via @SouljaBoy ! #Blessed',
#   {'entities': [(0, 6, 'B-person'), (7, 10, 'I-person')]}],
#  ["Stephen , the Intellectual . @bbhess I bet ppl that design book covers for a living hate when people say do n't judge a book by its cover",
#   {'entities': [(0, 7, 'B-person')]}],
#  ['Have DJ Got Us Fallin in Love in my head . " Cause baby tonight , The dj got us fallin in love again "',
#   {'entities': [(5, 7, 'B-creative-work'),
#     (8, 11, 'I-creative-work'),
#     (12, 14, 'I-creative-work'),
#     (15, 21, 'I-creative-work'),
#     (22, 24, 'I-creative-work'),
#     (25, 29, 'I-creative-work')]}],
#  ['@_AsToldByBV well i wrote you like 6 times this week ! urgh . RACHELLE im gonnauh kill YOU tonite !',
#   {'entities': [(62, 70, 'B-person')]}],
#  ["Before I proceed into the paradise , let 's not forget the Princess Lover OVA 1 teaser pic , SFW http://yfrog.com/0fg2kfj",
#   {'entities': [(59, 67, 'B-creative-work'),
#     (68, 73, 'I-creative-work'),
#     (74, 77, 'I-creative-work'),
#     (78, 79, 'I-creative-work')]}],
#  ['Pope Benedict trip : Why move John Henry Newman toward sainthood ?: Pope Benedict XVI plans on Sunday during his sta ... http://bit.ly/d7tM0r',
#   {'entities': [(0, 4, 'B-person'),
#     (5, 13, 'I-person'),
#     (30, 34, 'B-person'),
#     (35, 40, 'I-person'),
#     (41, 47, 'I-person'),
#     (68, 72, 'B-person'),
#     (73, 81, 'I-person'),
#     (82, 85, 'I-person')]}],
#  ['When you know what you want , and want it bad enough , you will find a way to get it . - Jim Rohn RT @TheSCICoach',
#   {'entities': [(89, 92, 'B-person'), (93, 97, 'I-person')]}],
#  ['last day of sorting pope visit to birmingham stuff out ..... hope it goes ok on sunday !!',
#   {'entities': [(20, 24, 'B-person'), (34, 44, 'B-location')]}],
#  ['Is Joaquin Phoenix Our Modern Day Andy Kaufman ?: ... the bizarre events leading up to this moment , the movie could ... http://bit.ly/aUZ2on',
#   {'entities': [(3, 10, 'B-person'),
#     (11, 18, 'I-person'),
#     (34, 38, 'B-person'),
#     (39, 46, 'I-person')]}],
#  ['RT @BiebersFairies : the day Justin Bieber was born was a rainy day , but it was no rain , NO ! the heaven was crying cause he lost his most ...',
#   {'entities': [(29, 35, 'B-person'), (36, 42, 'I-person')]}],
#  ['Exclusive : Rep . Steve King on ObamaCare , Tea Party , and Constitution Day : The inclusion of the Tenth Amendment in ... http://bit.ly/cYITA8',
#   {'entities': [(18, 23, 'B-person'), (24, 28, 'I-person')]}],
#  ['Lingerie football league come on tonight',
#   {'entities': [(0, 8, 'B-group'), (9, 17, 'I-group'), (18, 24, 'I-group')]}],
#  ["... four fucking years I 've been configuring iBGP and eBGP on Cisco AND Juniper routers for America 's largest wireless ISP ... and I get a 612",
#   {'entities': [(63, 68, 'B-corporation'),
#     (73, 80, 'B-corporation'),
#     (93, 100, 'B-location')]}],
#  ['Day at T . epic interview and photo shoot with Marie Clair . @OHEMMGEEZY',
#   {'entities': [(47, 52, 'B-corporation'), (53, 58, 'I-corporation')]}],
#  ['nightmare before christmas !!!',
#   {'entities': [(0, 9, 'B-creative-work'),
#     (10, 16, 'I-creative-work'),
#     (17, 26, 'I-creative-work')]}],
#  ['USM get ready yours truly tonight at frat house Hattiesburg on the 1s n 2s !!',
#   {'entities': [(0, 3, 'B-location'),
#     (37, 41, 'B-location'),
#     (42, 47, 'I-location'),
#     (48, 59, 'I-location')]}],
#  ['Lots of Merlot on Thursday night means tired London Ladies are in bed by 23.19 on the Friday . Listening to the arts show on @BBCRadio4 .',
#   {'entities': [(8, 14, 'B-product')]}],
#  ['Observances mark 9/11 anniversary : Observances in Temecula and elsewhere throughout the region last week marked the ... http://dlvr.it/5Rckw',
#   {'entities': [(51, 59, 'B-location')]}],
#  ['Honored Double Diaomond as well : Jan Bloom ... her two beautiful daughters surprised her on stage , it was just sooo ... http://fb.me/JLLhbDl0',
#   {'entities': [(34, 37, 'B-person'), (38, 43, 'I-person')]}],
#  ['RT @Quotealicious : Today , I saw a guy driving a Pepsi truck , drinking a Coke . MLIA #Quotealicious',
#   {'entities': [(50, 55, 'B-corporation'), (75, 79, 'B-product')]}],
#  ["@bookpage We should 've scheduled a meeting with Trisha in Paris for this week ... #deau",
#   {'entities': [(49, 55, 'B-person'), (59, 64, 'B-location')]}],
#  ["The Town might be one of the best movies I have seen all year . So , so good . And do n't worry Ben , we already forgave you for Gigli . Really .",
#   {'entities': [(0, 3, 'B-creative-work'),
#     (4, 8, 'I-creative-work'),
#     (96, 99, 'B-person'),
#     (129, 134, 'B-creative-work')]}],
# ...
#   {'entities': [(14, 20, 'B-person'),
#     (21, 30, 'I-person'),
#     (93, 96, 'B-corporation')]}],
#  ["Oh great time to change my Akron Zips password ... for the 12th semester . I'm all out of passwords damnit !",
#   {'entities': [(27, 32, 'B-group'), (33, 37, 'I-group')]}],
#  ['RT @josh_baldwin : Seahawks Sunday ! @WestWaYoungLife #ylgw15 http://t.co/pu5GS2Dhb4',
#   {'entities': [(19, 27, 'B-group')]}],
#  ['RT @Hardwick_SWFC : Fulham away is technically tomorrow , oh aye .',
#   {'entities': [(20, 26, 'B-group')]}],
#  ['RT @Things4GirIs : PSA RED VELVET OREOS COME OUT FEBRUARY 2nd RT TO SAVE A LIFE http://t.co/OCc3T5T1vu',
#   {'entities': [(23, 26, 'B-product'),
#     (27, 33, 'I-product'),
#     (34, 39, 'I-product')]}],
#  ["RT @Jonbuckhouse : Your right @GabbySidibe It is an amazing show ! Can't wait until Wednesday ! Your amazing Gabourey ! #Empire @EmpireFOX",
#   {'entities': [(109, 117, 'B-person')]}],
#  ['RT @nbcsnl : Getting ready for our final new show of 2014 . Gonna be a good one -- Amy Adams and @onedirection Saturday ! #SNL',
#   {'entities': [(83, 86, 'B-person'), (87, 92, 'I-person')]}],
#  ['( 2/2 ) Proud that the 1st modern Olympic Champion is James Brendan Connolly of #Southie . The world will see Boston at its finest #Boston2024',
#   {'entities': [(54, 59, 'B-person'),
#     (60, 67, 'I-person'),
#     (68, 76, 'I-person'),
#     (80, 88, 'B-location'),
#     (110, 116, 'B-location')]}],
#  ['Winter Weather Advisory has been issued for the following areas : East Slopes of the Washington Cascades-WA . Effective until 04:00 PM PST Sat',
#   {'entities': [(66, 70, 'B-location'),
#     (71, 77, 'I-location'),
#     (78, 80, 'I-location'),
#     (81, 84, 'I-location'),
#     (85, 95, 'I-location'),
#     (96, 107, 'I-location')]}],
#  ["Also having a hard time figuring out how CBHS is third in the D2 poll . Briarcrest is 5th , St . George 's 6th and Lausanne 10th .",
#   {'entities': [(41, 45, 'B-group'),
#     (72, 82, 'B-group'),
#     (92, 94, 'B-group'),
#     (95, 96, 'I-group'),
#     (97, 103, 'I-group'),
#     (115, 123, 'B-group')]}],
#  ["NASCAR 's Popular Regional Series , ACT Return to Help Celebrate 25th ... - RaceDayCT http://t.co/fYjrBS1QW0 #nascar",
#   {'entities': [(0, 6, 'B-corporation')]}],
#  ['RT @Zendaya : WISE Wednesday : If we did the things we are capable of doing , we would literally astound ourselves . ~ Thomas A Edison',
#   {'entities': [(119, 125, 'B-person'),
#     (126, 127, 'I-person'),
#     (128, 134, 'I-person')]}],
#  ["Another hour ! It 's December 19 , 2014 at 02:51 PM http://t.co/A7J0Q6CvBH ( via Twitter ..... http://t.co/VZgBlV2DR2 ) http://t.co/SEuyvw5B8q",
#   {'entities': [(81, 88, 'B-corporation')]}],
#  ['Picture Of City Of New York Fire Department Ladder Company 25 . Photo Taken Tuesday Janua ... http://t.co/lbohLRZwOD http://t.co/Xvs0iyVyKc',
#   {'entities': [(11, 15, 'B-location'),
#     (16, 18, 'I-location'),
#     (19, 22, 'I-location'),
#     (23, 27, 'I-location'),
#     (44, 50, 'B-group'),
#     (51, 58, 'I-group'),
#     (59, 61, 'I-group')]}],
#  ['RT @DatBabi___ : Dee Whit having something Saturday , ima slide through &amp; show my face .',
#   {'entities': [(17, 20, 'B-person'), (21, 25, 'I-person')]}],
#  ["@nynjpaweather I'm just hoping for a good nor'easter before I head back to oswego on the 25th",
#   {'entities': [(75, 81, 'B-location')]}],
#  ['Edison #weather on January 16 , 2015 - 01/16/2015 http://t.co/nFPkHS2KbO',
#   {'entities': [(0, 6, 'B-location')]}],
#  ["Saido Berahino couldn't match the form from his previous two Premier League appearances vs Everton on Monday night .",
#   {'entities': [(0, 5, 'B-person'),
#     (6, 14, 'I-person'),
#     (91, 98, 'B-group')]}],
#  ['RT @Guild_Gamer : So another article up for the PS4 tournament with some rules . Check it out http://t.co/XSJMR1UnKI',
#   {'entities': [(48, 51, 'B-product')]}],
#  ['RT @AquariusUnite : #Aquarians will not reveal their innermost feelings no matter how hard others may try to persuade them .',
#   {'entities': [(20, 30, 'B-group')]}],
#  ['RT @TheOLLGTeam : if justin bieber is gonna surprise ELLEN tomorrow , I will cry for days',
#   {'entities': [(21, 27, 'B-person'),
#     (28, 34, 'I-person'),
#     (53, 58, 'B-person')]}],
#  ['Party /w @BrianFoxx &amp; @MixxPromotions Thurs @ Sutra ! #JerkChicken RSVP By texting SUTRA to 33733 http://t.co/j0G2ofktJz',
#   {'entities': [(50, 55, 'B-location')]}],
#  ['The Xbox one may be the greatest thing ever',
#   {'entities': [(4, 8, 'B-product'), (9, 12, 'I-product')]}],
#  ['" JUST IN : DEMI LOVATO is coming to Manila on April 30 , 2015 @moaarena @wilbroslive @ddlovato #DemiLovatoWorldTourMNL " I\'M DEAD WAHHH',
#   {'entities': [(12, 16, 'B-person'),
#     (17, 23, 'I-person'),
#     (37, 43, 'B-location')]}],
#  ['RT @IAmJohnSparks : RETWEET &amp; REMEMBER Cowboys Kickoff Is At 12:05 P.M. Dallas Time Tomorrow ! #CowboysNation http://t.co/Iq8MNrFlud',
#   {'entities': [(43, 50, 'B-group'), (76, 82, 'B-location')]}],
#  ['Titan 3 Potros 2 [ Top 5th ] [ 0 Out ] [ 0 balls ] [ 0 strikes ] ... No one on [ P : #23 Steven Alejandro ] [ B : #27 Player 2 ]',
#   {'entities': [(89, 95, 'B-person'), (96, 105, 'I-person')]}],
#  ['@MarkoMkTwo Not looking promising mate , still shitloads of tax returns to do , probably be doing Olly Bernards on the 31st @RILEYENNIS',
#   {'entities': [(98, 102, 'B-person'), (103, 111, 'I-person')]}],
#  ['Walmart ! &lt; a href= " http://t.co/WQFTmb38S7 " &gt; Start Strong , Save Big during the January Savings Event at Walmart ! http://t.co/a2mD3Hy4xo',
#   {'entities': [(0, 7, 'B-corporation'), (115, 122, 'B-corporation')]}],
#  ['#Orlando weather January 13 , 14 , 15 , 16 , 17 , 18 2015 http://t.co/m6Mli6Bxa6',
#   {'entities': [(0, 8, 'B-location')]}],
#  ['RT @WINDmobile : ReadySetGo ! RT in the next 5min for a chance to win the 27th #Nexus6 ! #BirthdayGift http://t.co/icNQXFdij0',
#   {'entities': [(79, 86, 'B-product')]}],
#  ["Thursday : Ukulele Night all welcome $10 first drink free . / Friday : Temple Of The Grunge ( NZ 's best grunge act) ... http://t.co/Izztn63NJO",
#   {'entities': [(71, 77, 'B-group'),
#     (78, 80, 'I-group'),
#     (81, 84, 'I-group'),
#     (85, 91, 'I-group')]}],
#  ['#8825 Panasonic AG-HMC40P Professional 3mos AVCCAM http://t.co/4kNaSwaKKg $ 599.00 ( 0 Bids ) End Date : Saturday ... http://t.co/R87eCWkGq2',
#   {'entities': [(6, 15, 'B-product'),
#     (16, 25, 'I-product'),
#     (26, 38, 'I-product'),
#     (39, 43, 'I-product'),
#     (44, 50, 'I-product')]}],
#  ['Done with my 15th track on Soundcloud . :)',
#   {'entities': [(27, 37, 'B-corporation')]}],
#  ['off on Friday at 3pm I could be in Santa Fe by 930pm',
#   {'entities': [(35, 40, 'B-location'), (41, 43, 'I-location')]}],
#  ['" @JAYnFRESH : @BTAUKammyCakes_ come see us on the 31st " I Cant I Gotta Step Performance at Tha OaklandArtsSchool Thing If I Couldve I Wouldve',
#   {'entities': [(97, 114, 'B-location')]}],
#  ["istg its already 24 tomorrow yet i dont have luke 's follow im gonna cri",
#   {'entities': [(45, 49, 'B-person')]}],
#  ['@SairsP our flight is 1 of the only 5 that are leaving today from Venice ! Feeling very very #lucky . Hope to make it back on sunday ! @easyJet',
#   {'entities': [(66, 72, 'B-location')]}],
#  ['#9989 BOGEN / MANFROTTO 501 HEAD with camera mounting plate http://t.co/UN11lHxESG $ 150.00 End Date : Friday Ja ... http://t.co/iQiuPeO0PA',
#   {'entities': [(6, 11, 'B-product'),
#     (12, 13, 'I-product'),
#     (14, 23, 'I-product'),
#     (24, 27, 'I-product'),
#     (28, 32, 'I-product'),
#     (33, 37, 'I-product'),
#     (38, 44, 'I-product'),
#     (45, 53, 'I-product'),
#     (54, 59, 'I-product')]}],
#  ['If a child burps during a church service in Omaha , his or her parents may be arrested . #StrangeLaws in Nebraska',
#   {'entities': [(44, 49, 'B-location'), (105, 113, 'B-location')]}],
#  ['@TitoElmasduro Please share ! Lolita the Orca Classified as Endangered ; Groups May Now Sue to Force Her Release http://t.co/hrkyfj46Hs',
#   {'entities': [(30, 36, 'B-person')]}],
#  ['RT @Newsroompostcom : LIVE : BJP may release its vision document for Delhi polls today http://t.co/VZ78in0bky http://t.co/8xtSWzvu5I',
#   {'entities': [(29, 32, 'B-corporation'), (69, 74, 'B-location')]}],
#  ["Jake Paul c'est mon viner fav avec Logan puaind fdjvfdlkvjfdlkv",
#   {'entities': [(0, 4, 'B-person'),
#     (5, 9, 'I-person'),
#     (35, 40, 'B-person')]}],
#  ['RT @thefairchilds : Time for some lyrics w/ gorgeous Guild Guitars D55 ... Tomorrow , back to LALALAND ! http://t.co/WyTU1WuXZS',
#   {'entities': [(53, 58, 'B-product'),
#     (59, 66, 'I-product'),
#     (67, 70, 'I-product')]}],
#  ['A local veteran Army nurse will receive the highest honor from France tomorrow for her service to our country . http://t.co/Ewv0XaSPuM',
#   {'entities': [(16, 20, 'B-group'), (63, 69, 'B-location')]}],
#  ['RT @maxwellkandler : RT if you would rather come over and watch netflix with me instead of going to school tomorrow',
#   {'entities': [(64, 71, 'B-corporation')]}],
#  ['Pre Order Jaket Korea BARCA " RIDE " sd 7 Jan , 185K belum ongkir @bcannon241 SMS/WA 081235994171 pin 512A3491 http://t.co/8V2X1RSPYO',
#   {'entities': [(10, 15, 'B-product'),
#     (16, 21, 'I-product'),
#     (22, 27, 'I-product'),
#     (28, 29, 'I-product'),
#     (30, 34, 'I-product'),
#     (35, 36, 'I-product')]}],
#  ['New artwork for sale ! - " Saturday Night Live in Beantown " - http://t.co/MvPiaZ3rHR',
#   {'entities': [(27, 35, 'B-creative-work'),
#     (36, 41, 'I-creative-work'),
#     (42, 46, 'I-creative-work'),
#     (47, 49, 'I-creative-work'),
#     (50, 58, 'I-creative-work')]}],
#  ['CoreLogic US home prices jump nearly 12 percent in June - See more at',
#   {'entities': [(0, 9, 'B-corporation'), (10, 12, 'B-location')]}],
#  ["Pluto didn't even complete one revolution around the sun between its discovery and its declassification as a planet . #random",
#   {'entities': [(0, 5, 'B-location')]}],
#  ['Our own Richard Smith is on the scene for the Terps-Illini game : http://t.co/OMLAs7Msv7',
#   {'entities': [(8, 15, 'B-person'),
#     (16, 21, 'I-person'),
#     (46, 58, 'B-group')]}],
#  ['Rihanna at GQ Men Of The Year Party - Red Carpet http://t.co/GgKsppRdjS',
#   {'entities': [(0, 7, 'B-person')]}],
#  ['RT @chickmcgee1 : " Learn from yesterday , live for today , hope for tomorrow ." -- Albert Einstein',
#   {'entities': [(84, 90, 'B-person'), (91, 99, 'I-person')]}],
#  ['RT @ThaliaSource : SCANS : @Thalia Hola Mexico December 24 , 2014 http://t.co/o5x6yp5FBa http://t.co/1fHXTR0NMP',
#   {'entities': [(40, 46, 'B-location')]}],
#  ['In 8th grade we had a debate on immigration . It was not even a debate it was more like everyone yell at Ashley and make her cry .',
#   {'entities': [(105, 111, 'B-person')]}],
#  ['Serena Williams Vs Simona Halep WTA Finals Singapore Open 2014 Round Robin 2nd Set by Te ... http://t.co/HP1FuGXeZU http://t.co/omtIu3Q9mj',
#   {'entities': [(0, 6, 'B-person'),
#     (7, 15, 'I-person'),
#     (19, 25, 'B-person'),
#     (26, 31, 'I-person'),
#     (43, 52, 'B-location')]}],
#  ["Gonna go HMV tomorrow but do I buy Enter Shikari 's Mindsweep or that Crobot album that I could eventually be sent for free ?",
#   {'entities': [(9, 12, 'B-corporation'),
#     (35, 40, 'B-group'),
#     (41, 48, 'I-group'),
#     (52, 61, 'B-creative-work'),
#     (70, 76, 'B-group')]}],
#  ['Congrats Greyhounds ! #CarmelIN MT @carmelathletics Girls basketball defeats Kokomo 68-37 . Hounds host NC on Friday .',
#   {'entities': [(9, 19, 'B-group'),
#     (77, 83, 'B-group'),
#     (92, 98, 'B-group'),
#     (104, 106, 'B-group')]}],
#  ['We Want KathNiel Lovestory On MMK trending 3rd Spot ! #KathrynBernardoTheMMKComeback 2nd Spot !',
#   {'entities': [(8, 16, 'B-creative-work'),
#     (17, 26, 'I-creative-work'),
#     (30, 33, 'B-corporation')]}],
#  ['RT @History_Pics : January is named after the Roman god Janus . He had two faces to see the future and the past . http://t.co/zEWGvmRADb',
#   {'entities': [(56, 61, 'B-person')]}],
#  ["So the next ' A Song Of Ice &amp; Fire ' book won't be out this year at all . Have to do with more Dunc &amp; Egg prequels then ! http://t.co/wfxPsIgGao",
#   {'entities': [(14, 15, 'B-creative-work'),
#     (16, 20, 'I-creative-work'),
#     (21, 23, 'I-creative-work'),
#     (24, 27, 'I-creative-work'),
#     (28, 33, 'I-creative-work'),
#     (34, 38, 'I-creative-work')]}],
#  ['Sign up for the Middle East and Africa December Regional Debate on the topic of Enhancing Political Stability in ... http://t.co/P398sR4wta',
#   {'entities': [(16, 22, 'B-location'),
#     (23, 27, 'I-location'),
#     (32, 38, 'B-location')]}],
#  ['Jan Fredrik , litt mye ? #engasjert #mittdansecrew',
#   {'entities': [(0, 3, 'B-person'), (4, 11, 'I-person')]}],
#  ["The new hall @TheBulmersheSch getting ready for the 6th form open evening on 22 Jan and Gala evg ' Grease ' on 11 Feb http://t.co/LBTBjgzdGx",
#   {'entities': [(99, 105, 'B-creative-work')]}],
#  ["Candlelight vigil scheduled for John Paul Quintero , man shot by Wichita police , tomorrow night at St . Mark's. http://t.co/ODZPuFVYqF",
#   {'entities': [(32, 36, 'B-person'),
#     (37, 41, 'I-person'),
#     (42, 50, 'I-person'),
#     (65, 72, 'B-location'),
#     (100, 102, 'B-location'),
#     (103, 104, 'I-location'),
#     (105, 112, 'I-location')]}],
#  ["RT @DBLesky : Here 's an idea . Ernie Banks Day . Pick a Saturday every year and every team plays a scheduled double header that day .",
#   {'entities': [(32, 37, 'B-person'), (38, 43, 'I-person')]}],
#  ['RT @dallascowboys : End of the 3rd : Cowboys 28 , Eagles 24 http://t.co/QGBMGU3w3o http://t.co/Wpnpp7Sn1i',
#   {'entities': [(37, 44, 'B-group'), (50, 56, 'B-group')]}],
#  ['RT @ESPNNFL : Tom Brady runs out for his 6th Super Bowl ! http://t.co/d5uHh7fbDy',
#   {'entities': [(14, 17, 'B-person'), (18, 23, 'I-person')]}],
#  ['Jason Industries to Hold Annual Meeting of Stockholders on May 20 http://t.co/6BAzXxZqfO',
#   {'entities': [(0, 5, 'B-corporation'), (6, 16, 'I-corporation')]}],
#  ['" Junk food may not kill us directly , but by prompting the collapse of .. a mutually beneficial symbiosis ." -Velasquez-Manoff #diet',
#   {'entities': [(110, 127, 'B-person')]}],
#  ['RT @DayTraders1 : NADT Affiliate : 14th MENA FOREX EXPO Announce . http://t.co/OI5UezRRlv #forex',
#   {'entities': [(18, 22, 'B-group')]}],
#  ['The Ascension disrespects The New World Order : Raw , January 19 , 2015 http://t.co/F4dGtYqHqE http://t.co/bLWMU6TfUe',
#   {'entities': [(0, 3, 'B-group'),
#     (4, 13, 'I-group'),
#     (26, 29, 'B-group'),
#     (30, 33, 'I-group'),
#     (34, 39, 'I-group'),
#     (40, 45, 'I-group')]}],
#  ["It has been a who 's who of alumni at the Hawk 's Nest . Who will there tomorrow ? The young ones can learn a lot .",
#   {'entities': [(42, 46, 'B-location'),
#     (47, 49, 'I-location'),
#     (50, 54, 'I-location')]}],
#  ['RT @nfl : Peyton Manning has now eclipsed 4,000 passing yards for the 14th time in his NFL career . #Boss http://t.co/VMQ0D0r1yK',
#   {'entities': [(10, 16, 'B-person'),
#     (17, 24, 'I-person'),
#     (87, 90, 'B-group')]}],
#  ['RT @blackvoices : Willie Mae " Big Mama " Thornton was born today December 11th , in 1926 . http://t.co/04P5I9VIA7',
#   {'entities': [(18, 24, 'B-person'),
#     (25, 28, 'I-person'),
#     (29, 30, 'I-person'),
#     (31, 34, 'I-person'),
#     (35, 39, 'I-person'),
#     (40, 41, 'I-person'),
#     (42, 50, 'I-person')]}],
#  ["I'm leaving yakima on Wednesday ughh goal is not cry",
#   {'entities': [(12, 18, 'B-location')]}],
#  ['Pre Order jaket Korea CHELSEA " RIDE " sd 7 Jan , 185K belum ongkir @rio_intan SMS/WA 081235994171 pin 512A3491 http://t.co/qvN7jhp0II',
#   {'entities': [(10, 15, 'B-product'),
#     (16, 21, 'I-product'),
#     (22, 29, 'I-product'),
#     (30, 31, 'I-product'),
#     (32, 36, 'I-product'),
#     (37, 38, 'I-product'),
#     (39, 41, 'I-product')]}],
#  ["Yay , there 's finally a gas station on Green Valley Pkwy . @andreadomanick has a map and everything http://t.co/ZhQbRYx2Qv @LasVegasSun",
#   {'entities': [(40, 45, 'B-location'),
#     (46, 52, 'I-location'),
#     (53, 57, 'I-location')]}],
#  ['RT @pham1717 : They picked up right where they left off Wednesday . Their coverage is horrendous . Another PP goal against , 2-0 Panthers .',
#   {'entities': [(129, 137, 'B-group')]}],
#  ...]

# %% [markdown]
# STEP:2 FUNCTIONS TO CALCULATE EVALUVATION METRICS

# %%
def calc_precision(pred, true):        
    precision = len([x for x in pred if x in true]) / (len(pred) + 1e-20) # true positives / total pred
    return precision

def calc_recall(pred, true):
    recall = len([x for x in true if x in pred]) / (len(true) + 1e-20)    # true positives / total test
    return recall

def calc_f1(precision, recall):
    f1 = 2 * ((precision * recall) / (precision + recall + 1e-20))
    return f1

# %%
def evaluate(ner, data):
    preds = [ner(x[0]) for x in data]

    precisions, recalls, f1s = [], [], []

    for pred, true in zip(preds, data):
        true = [x[2] for x in list(chain.from_iterable(true[1].values()))]
        pred = [i.label_ for i in pred.ents]
        precision = calc_precision(true, pred)
        precisions.append(precision)
        recall = calc_recall(true, pred)
        recalls.append(recall)
        f1s.append(calc_f1(precision, recall))

    return {"textcat_p": np.mean(precisions), "textcat_r": np.mean(recalls), "textcat_f":np.mean(f1s)}

# %% [markdown]
# STEP:3 FUNCTION TO TRAIN THE CNN MODEL

# %%
def train_spacy(train_data, labels, iterations, dropout = 0.5, display_freq = 1):
    
    valid_f1scores=[]
    test_f1scores=[]
    
    model = None
    
    nlp = spacy.load("en_core_web_sm")
    
    if model is not None:
        nlp = spacy.load(model) 
        print("Loaded model '%s'" % model)
    else:
        nlp = spacy.blank('en')
        print("Created blank 'en' model")
        
    if "ner" not in nlp.pipe_names:
        ner = nlp.create_pipe("ner")
        nlp.add_pipe('ner', last=True)
    
    else:
        ner = nlp.get_pipe("ner")
        
    for _, annotations in train_data:
        for ent in annotations.get('entities'):
            ner.add_label(ent[2])
            
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    
    with nlp.disable_pipes(*other_pipes), warnings.catch_warnings():
        warnings.filterwarnings("once", category=UserWarning, module='spacy')
        if model is None:
            nlp.begin_training()
        optimizer = nlp.initialize()
        for itn in range(iterations):
            random.shuffle(train_data)
            losses = {}
            batches = minibatch(TRAIN_DATA, size=compounding(4.0, 32.0, 1.001))
            for text, annotation in train_data:
                example = Example.from_dict(nlp.make_doc(text), annotation)
                nlp.update(          
                    [example],
                    drop = dropout,  
                    sgd = optimizer,
                    losses = losses)

            scores = evaluate(nlp,VALID_DATA)
            valid_f1scores.append(scores["textcat_f"])
            print('=======================================')
            print('Interation = '+str(itn+1))
            print('Losses = '+str(losses))
            print('===============VALID DATA========================')
            
            print('F1-score = '+str(scores["textcat_f"]))
            print('Precision = '+str(scores["textcat_p"]))
            print('Recall = '+str(scores["textcat_r"]))
            
    return nlp,valid_f1scores,test_f1scores

# %% [markdown]
# STEP:4 RUNNING THE MODEL AND SAVING IT IN A LOCAL DIRECTORY

# %%
ner,valid_f1scores,test_f1scores = train_spacy(TRAIN_DATA, LABELS,50)
ner.to_disk("C:\Codes and resources\Codes\infrrd")
# Out:
# Created blank 'en' model
# =======================================
# Interation = 1
# Losses = {'ner': 5070.352267130611}
# ===============VALID DATA========================
# F1-score = 0.25873385873385873
# Precision = 0.2308608058608059
# Recall = 0.3269230769230769
# =======================================
# Interation = 2
# Losses = {'ner': 4245.313856270026}
# ===============VALID DATA========================
# F1-score = 0.3511069340016708
# Precision = 0.35213675213675216
# Recall = 0.3758241758241759
# =======================================
# Interation = 3
# Losses = {'ner': 3882.9839151664037}
# ===============VALID DATA========================
# F1-score = 0.4166151930857813
# Precision = 0.4191900691900692
# Recall = 0.4559829059829059
# =======================================
# Interation = 4
# Losses = {'ner': 3672.171075441074}
# ===============VALID DATA========================
# F1-score = 0.45111925111925105
# Precision = 0.4551282051282051
# Recall = 0.48290598290598286
# =======================================
# Interation = 5
# Losses = {'ner': 3445.798167085043}
# ===============VALID DATA========================
# F1-score = 0.38403404962109416
# Precision = 0.3804029304029304
# Recall = 0.4243589743589743
# =======================================
# Interation = 6
# Losses = {'ner': 3345.528188522912}
# ===============VALID DATA========================
# F1-score = 0.45622013487867147
# Precision = 0.44618437118437115
# Recall = 0.5032051282051282
# =======================================
# Interation = 7
# Losses = {'ner': 3227.3611591837744}
# ===============VALID DATA========================
# F1-score = 0.41327191327191326
# Precision = 0.4032661782661783
# Recall = 0.47350427350427354
# =======================================
# Interation = 8
# Losses = {'ner': 3004.4368293269067}
# ===============VALID DATA========================
# F1-score = 0.39303196803196805
# Precision = 0.3796398046398046
# Recall = 0.4423076923076923
# =======================================
# Interation = 9
# Losses = {'ner': 2826.0907706449902}
# ===============VALID DATA========================
# F1-score = 0.4087716414639492
# Precision = 0.3952075702075702
# Recall = 0.45940170940170943
# =======================================
# Interation = 10
# Losses = {'ner': 2901.551210085296}
# ===============VALID DATA========================
# F1-score = 0.39749266328213695
# Precision = 0.4074175824175824
# Recall = 0.4264957264957265
# =======================================
# Interation = 11
# Losses = {'ner': 2730.0689953161327}
# ===============VALID DATA========================
# F1-score = 0.4170427067485892
# Precision = 0.4065018315018315
# Recall = 0.45726495726495725
# =======================================
# Interation = 12
# Losses = {'ner': 2604.48058859934}
# ===============VALID DATA========================
# F1-score = 0.4614377703744219
# Precision = 0.45451770451770457
# Recall = 0.5042735042735043
# =======================================
# Interation = 13
# Losses = {'ner': 2487.178048039491}
# ===============VALID DATA========================
# F1-score = 0.42839638156380233
# Precision = 0.41674806674806675
# Recall = 0.4861111111111111
# =======================================
# Interation = 14
# Losses = {'ner': 2356.4590426301493}
# ===============VALID DATA========================
# F1-score = 0.4095362502245093
# Precision = 0.4203907203907204
# Recall = 0.4290598290598291
# =======================================
# Interation = 15
# Losses = {'ner': 2363.532240629053}
# ===============VALID DATA========================
# F1-score = 0.46254087043560727
# Precision = 0.4815934065934066
# Recall = 0.4724358974358975
# =======================================
# Interation = 16
# Losses = {'ner': 2168.4034738748564}
# ===============VALID DATA========================
# F1-score = 0.45220705474663053
# Precision = 0.45228937728937724
# Recall = 0.49444444444444446
# =======================================
# Interation = 17
# Losses = {'ner': 2145.209348852973}
# ===============VALID DATA========================
# F1-score = 0.4542143821091189
# Precision = 0.46526251526251516
# Recall = 0.4818376068376068
# =======================================
# Interation = 18
# Losses = {'ner': 2022.053835703759}
# ===============VALID DATA========================
# F1-score = 0.45081037369967947
# Precision = 0.4446581196581197
# Recall = 0.4914529914529914
# =======================================
# Interation = 19
# Losses = {'ner': 2009.0389977199407}
# ===============VALID DATA========================
# F1-score = 0.47103090317241186
# Precision = 0.47045177045177045
# Recall = 0.5038461538461538
# =======================================
# Interation = 20
# Losses = {'ner': 1895.011716703834}
# ===============VALID DATA========================
# F1-score = 0.48854391509190265
# Precision = 0.4822039072039072
# Recall = 0.5166666666666666
# =======================================
# Interation = 21
# Losses = {'ner': 1839.4528526626389}
# ===============VALID DATA========================
# F1-score = 0.4367449071396439
# Precision = 0.42084859584859585
# Recall = 0.4935897435897436
# =======================================
# Interation = 22
# Losses = {'ner': 1871.9754109625458}
# ===============VALID DATA========================
# F1-score = 0.47201042421630646
# Precision = 0.45228937728937735
# Recall = 0.5363247863247863
# =======================================
# Interation = 23
# Losses = {'ner': 1663.2352723175086}
# ===============VALID DATA========================
# F1-score = 0.43209426075279733
# Precision = 0.4121489621489622
# Recall = 0.4850427350427351
# =======================================
# Interation = 24
# Losses = {'ner': 1680.2228913702265}
# ===============VALID DATA========================
# F1-score = 0.4618261431079767
# Precision = 0.466025641025641
# Recall = 0.4974358974358974
# =======================================
# Interation = 25
# Losses = {'ner': 1700.621452499231}
# ===============VALID DATA========================
# F1-score = 0.4752763103769296
# Precision = 0.45549450549450543
# Recall = 0.5331196581196581
# =======================================
# Interation = 26
# Losses = {'ner': 1596.976355559161}
# ===============VALID DATA========================
# F1-score = 0.43075171104463794
# Precision = 0.41474358974358977
# Recall = 0.4725274725274725
# =======================================
# Interation = 27
# Losses = {'ner': 1515.605395741186}
# ===============VALID DATA========================
# F1-score = 0.4829079602358954
# Precision = 0.4725885225885226
# Recall = 0.5319291819291819
# =======================================
# Interation = 28
# Losses = {'ner': 1482.4962112344654}
# ===============VALID DATA========================
# F1-score = 0.4995980532565898
# Precision = 0.5218864468864469
# Recall = 0.5163308913308914
# =======================================
# Interation = 29
# Losses = {'ner': 1435.391273770726}
# ===============VALID DATA========================
# F1-score = 0.5211969979110447
# Precision = 0.5302808302808303
# Recall = 0.5535103785103784
# =======================================
# Interation = 30
# Losses = {'ner': 1468.982466781563}
# ===============VALID DATA========================
# F1-score = 0.46539920809622704
# Precision = 0.49120879120879124
# Recall = 0.4748778998778999
# =======================================
# Interation = 31
# Losses = {'ner': 1314.5896696041987}
# ===============VALID DATA========================
# F1-score = 0.47020862914528067
# Precision = 0.47609890109890113
# Recall = 0.5027777777777777
# =======================================
# Interation = 32
# Losses = {'ner': 1292.9482770360767}
# ===============VALID DATA========================
# F1-score = 0.5399883592191284
# Precision = 0.5659951159951161
# Recall = 0.5393772893772893
# =======================================
# Interation = 33
# Losses = {'ner': 1231.5891858966002}
# ===============VALID DATA========================
# F1-score = 0.5020821664986423
# Precision = 0.5183760683760684
# Recall = 0.5309829059829061
# =======================================
# Interation = 34
# Losses = {'ner': 1275.798706952767}
# ===============VALID DATA========================
# F1-score = 0.5049442182731307
# Precision = 0.5357753357753356
# Recall = 0.5131868131868131
# =======================================
# Interation = 35
# Losses = {'ner': 1254.1014309357158}
# ===============VALID DATA========================
# F1-score = 0.44863068691956515
# Precision = 0.45778388278388277
# Recall = 0.46324786324786327
# =======================================
# Interation = 36
# Losses = {'ner': 1276.002841796129}
# ===============VALID DATA========================
# F1-score = 0.43445762514588426
# Precision = 0.4332112332112332
# Recall = 0.47179487179487184
# =======================================
# Interation = 37
# Losses = {'ner': 1249.946551698866}
# ===============VALID DATA========================
# F1-score = 0.4938618304151039
# Precision = 0.49761904761904757
# Recall = 0.5241452991452992
# =======================================
# Interation = 38
# Losses = {'ner': 1193.8211954919893}
# ===============VALID DATA========================
# F1-score = 0.4596687425634794
# Precision = 0.48205128205128206
# Recall = 0.46944444444444455
# =======================================
# Interation = 39
# Losses = {'ner': 1144.7421621076069}
# ===============VALID DATA========================
# F1-score = 0.5245396315722994
# Precision = 0.5414224664224664
# Recall = 0.5514957264957265
# =======================================
# Interation = 40
# Losses = {'ner': 1066.819898747556}
# ===============VALID DATA========================
# F1-score = 0.4731425981425981
# Precision = 0.47884615384615375
# Recall = 0.50491452991453
# =======================================
# Interation = 41
# Losses = {'ner': 1048.4629804634778}
# ===============VALID DATA========================
# F1-score = 0.5009548691284001
# Precision = 0.5151709401709402
# Recall = 0.5305250305250305
# =======================================
# Interation = 42
# Losses = {'ner': 1092.9205281395778}
# ===============VALID DATA========================
# F1-score = 0.4805456669233759
# Precision = 0.48479853479853485
# Recall = 0.5121794871794872
# =======================================
# Interation = 43
# Losses = {'ner': 1108.1644216169466}
# ===============VALID DATA========================
# F1-score = 0.4066261719139733
# Precision = 0.41978021978021984
# Recall = 0.42206959706959707
# =======================================
# Interation = 44
# Losses = {'ner': 1125.8435805450003}
# ===============VALID DATA========================
# F1-score = 0.43727410690973445
# Precision = 0.4577838827838829
# Recall = 0.4726800976800977
# =======================================
# Interation = 45
# Losses = {'ner': 1036.5004100011718}
# ===============VALID DATA========================
# F1-score = 0.49329280879345067
# Precision = 0.5063186813186813
# Recall = 0.5260989010989011
# =======================================
# Interation = 46
# Losses = {'ner': 1079.2719879854794}
# ===============VALID DATA========================
# F1-score = 0.5118647592007153
# Precision = 0.5281440781440782
# Recall = 0.5402014652014652
# =======================================
# Interation = 47
# Losses = {'ner': 1068.5525009906999}
# ===============VALID DATA========================
# F1-score = 0.38265550525612446
# Precision = 0.3941391941391941
# Recall = 0.3923076923076923
# =======================================
# Interation = 48
# Losses = {'ner': 996.1457588982324}
# ===============VALID DATA========================
# F1-score = 0.3767848164906988
# Precision = 0.3759768009768009
# Recall = 0.391025641025641
# =======================================
# Interation = 49
# Losses = {'ner': 1017.4217466238997}
# ===============VALID DATA========================
# F1-score = 0.4498747678974922
# Precision = 0.46572039072039073
# Recall = 0.4710622710622711
# =======================================
# Interation = 50
# Losses = {'ner': 931.5386340119495}
# ===============VALID DATA========================
# F1-score = 0.45426504081243296
# Precision = 0.4738095238095238
# Recall = 0.4747252747252747

# %% [markdown]
# STEP:5 LOADING TEST DATA, PRE-PROCESSING & TESTING IT ON THE SAVED MODEL

# %%
spacy_df = pd.read_csv('test.txt', sep=' ', quoting=csv.QUOTE_NONE, skip_blank_lines = False, header=None)
spacy_df['Sentence #'] = ''
i = 0
for ind in spacy_df.index-1:
    if type(spacy_df.iloc[ind,0])==float:
        i = i+1
        spacy_df.iloc[ind+1,1] = 'Sentence: ' + str(i)
    spacy_df.iloc[ind,1] = 'Sentence: ' + str(i)
spacy_df = spacy_df.dropna()

# %%
agg_func = lambda s: [ w for w in s[0]]
TEST_DATA = spacy_df.groupby("Sentence #").apply(agg_func)

# %%
def load_model(model_path):
    nlp = spacy.blank('en')
    if 'ner' not in nlp.pipe_names:
        ner = nlp.create_pipe('ner')
        nlp.add_pipe('ner')
    ner = nlp.from_disk(model_path)
    return ner

# %%
ner = load_model("C:\Codes and resources\Codes\infrrd")

test_sentences = [' '.join(x) for x in TEST_DATA]
for x in test_sentences:
    doc = ner(x)
    for ent in doc.ents:
        print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Defence 138 145 B-person
# Spokesman 146 155 I-person
# Colonel 156 163 I-person
# Kalia 171 176 B-location
# Juve 50 54 B-person
# Verratti 55 63 I-person
# M 80 81 B-person
# Leel 5 9 B-person
# Not 10 13 B-group
# Answers 14 21 I-product
# | 22 23 I-corporation
# Box 24 27 I-product
# of 28 30 I-group
# Crayons 31 38 I-group
# female 31 37 B-person
# jungkook 62 70 B-person
# Donald 18 24 B-person
# Nazaire 5 12 B-creative-work
# Trump 18 23 B-person
# Appalachia 57 67 B-person
# 5 16 17 B-group
# Highest 18 25 I-product
# Young 60 65 B-person
# Ae 66 68 I-person
# Saimdang 71 79 B-group
# Diary 92 97 I-creative-work
# Billion 109 116 B-person
# oi 13 15 B-location
# Kid 6 9 B-person
# Development 51 62 B-creative-work
# katarina 2 10 B-location
# Trump 78 83 B-person
# Collaborations 14 28 B-person
# Sims 36 40 B-location
# Uroxatral 0 9 I-location
# Gandalf 10 17 B-person
# SoCal 35 40 B-location
# meoss 5 10 B-corporation
# MarioLopezExtra 5 20 B-location
# Willpower 2 11 B-group
# Coe 0 3 B-person
# Glasgow 43 50 B-location
# Max 88 91 B-group
# Maria 62 67 B-person
# LadyThriller 20 32 B-location
# dope 100 104 B-person
# Increasing 19 29 B-corporation
# Kaaaatie 5 13 B-location
# Money 12 17 B-corporation
# Ain 18 21 I-corporation
# A 26 27 I-person
# Problem 28 35 I-group
# Feat 36 40 I-location
# Montana 50 57 I-corporation
# Diddy 61 66 I-person
# 50 18 20 B-person
# Cent 21 25 I-person
# Hey 0 3 B-location
# LOOK 4 8 I-person
# Bellarmine 36 46 B-location
# Vanished 13 21 B-person
# Podcast 24 31 B-location
# Helped 32 38 I-location
# Solve 39 44 I-product
# DJ 5 7 I-creative-work
# Show 8 12 I-creative-work
# Jack 0 4 B-person
# Gilinsky 5 13 I-person
# Muslim 19 25 I-product
# Moonlight 42 51 I-group
# Mitch 36 41 B-person
# 💰 42 43 I-person
# Konnan 5 11 B-creative-work
# Leicester 40 49 B-creative-work
# Europa 91 97 B-person
# league 98 104 I-person
# 🔴 LIVE 0 6 B-product
# 1 63 64 I-product
# Z 65 66 I-product
# Late 73 77 B-group
# Night 78 83 I-location
# Battlefield 84 95 I-location
# Huron 32 37 B-group
# mccabe 7 13 B-corporation
# Google 46 52 B-product
# StefanMolyneux 62 76 B-group
# WORIDSTARHlPHOP 5 20 B-location
# Mets 12 16 B-group
# Building 0 8 I-location
# Others 39 45 B-location
# Hard 49 53 B-person
# Work 54 58 I-person
# Foxy 50 54 B-group
# UpornTube 5 14 B-corporation
# Schofe 2 8 B-location
# C 11 12 B-location
# 4 13 14 I-location
# Gogglebox 15 24 I-location
# NorahRab 30 38 B-product
# KODE 17 21 B-group
# Action 22 28 I-group
# of 29 31 I-creative-work
# Monkeys 32 39 I-creative-work
# Ireland 63 70 B-location
# # UC 0 4 B-group
# Into 53 57 B-person
# Wild 62 66 B-person
# Race 0 4 B-group
# Recap 5 10 I-group
# CrapTaxidermy 5 18 B-group
# ATA 0 3 I-location
# Of 39 41 I-group
# Reborn 15 21 B-person
# Jane 27 31 B-person
# Ederlyn 32 39 I-person
# What 6 10 I-creative-work
# Else 11 15 I-creative-work
# Costa 12 17 B-location
# Mind 3 7 I-product
# Boggling 8 16 I-product
# Facts 17 22 I-product
# DepCrusaderz 2 14 B-group
# # Birmingham 17 29 B-location
# kufr 76 80 B-person
# Police 81 87 I-person
# Harry 0 5 B-person
# Humour 13 19 I-creative-work
# BaszMM 59 65 B-group
# therapy 17 24 B-person
# support 38 45 B-location
# Niall 46 51 I-location
# Horan 52 57 I-location
# Frankfurt 44 53 B-corporation
# Radio 54 59 I-product
# Big 60 63 I-product
# Band 64 68 I-creative-work
# & amp ; 69 76 I-creative-work
# Behemoth 98 106 I-group
# CorporalMum 2 13 B-corporation
# # Diaperart 23 34 B-location
# LanaDelRey 5 15 B-group
# Music 18 23 B-creative-work
# To 24 26 I-creative-work
# Watch 27 32 I-creative-work
# Boys 33 37 I-creative-work
# YasminYonis 5 16 B-group
# Temp 0 4 B-corporation
# Dew 26 29 B-person
# podrìa 46 52 B-person
# Proposed 27 35 B-group
# . 59 60 I-person
# Miami 4 9 B-group
# Dolphins 10 18 I-group
# Dion 70 74 B-product
# Jordan 75 81 I-product
# Jimmy 0 5 B-person
# Fallon 6 12 I-person
# Shelton 25 32 I-location
# Hilarious 5 14 B-location
# Idiot 17 22 B-corporation
# JessieBelnap 5 17 B-location
# Hotel 39 44 B-location
# Housekeepers 45 57 I-product
# PreTape 10 17 B-location
# Ivanka 38 44 B-creative-work
# Lost 19 23 B-person
# MP 55 57 B-group
# # OsborneResign 99 114 B-group
# Beast 65 70 I-creative-work
# Joyous 108 114 B-person
# MadamMelanin 5 17 B-location
# Skai 20 24 B-person
# Jackson 25 32 I-person
# Untitled 37 45 B-group
# Magazine 46 54 I-location
# Genius 5 11 B-group
# SoundCloud 59 69 B-corporation
# Surprisingly 0 12 I-person
# # Kaye 27 33 B-product
# JacobRhines 2 13 B-person
# JacobWhitesides 5 20 B-location
# edsheeran 52 61 B-person
# Birmingham 22 32 B-person
# Helen 77 82 B-person
# Chikorita 6 15 B-location
# None 63 67 B-location
# Paramount 68 77 I-location
# Dr 78 80 I-location
# L 81 82 I-location
# Fresh 56 61 B-group
# Organic 66 73 B-group
# HuffPostWeird 2 15 B-person
# Paul 218 222 B-person
# STOPPED 2 9 B-corporation
# Jack 43 47 B-person
# Gilinsky 48 56 I-person
# Aquarius 78 86 B-group
# Blitz 14 19 B-person
# The 22 25 B-group
# Eslites 26 33 I-location
# CM 37 39 B-person
# Doporto 40 47 I-person
# Calgary 52 59 B-location
# Shadows 0 7 B-person
# Defenders - Multiplayer 27 50 B-location
# Isabella 65 73 B-group
# CBC 37 40 B-person
# Manitoba 41 49 I-person
# teen 0 4 B-person
# BeautyOfAnAries 5 20 B-corporation
# NBC 66 69 B-location
# Trump 85 90 B-person
# Swift 2 7 B-person
# Mahazgund 83 92 B-person
# Diego 27 32 B-person
# Rolan 33 38 I-person
# PSG 47 50 B-group
# OmniDestiny 2 13 B-creative-work
# Hozay 5 10 B-person
# Italy 41 46 B-location
# Olive 80 85 B-corporation
# Garden 86 92 I-person
# Amitabh 5 12 B-person
# joy 75 78 B-person
# Bitter 32 38 B-location
# S 0 1 B-creative-work
# A 2 3 I-creative-work
# I 4 5 I-creative-work
# Dinko 29 34 B-group
# English 24 31 B-group
# ricardojkay 5 16 B-group
# Sound 13 18 B-product
# Crazy 19 24 I-person
# Notttttt 53 61 B-product
# Hang 62 66 I-product
# With 67 71 I-product
# People 72 78 I-creative-work
# Don 83 86 B-person
# LlTFREESTYLES 5 18 B-person
# Rastus 26 32 B-location
# Pete 37 41 B-person
# ChicanoBatman 24 37 B-product
# TheValerieJune 61 75 B-corporation
# # SXSW 86 92 B-location
# VuHaus 125 131 B-location
# Jack 40 44 B-person
# Pearson 45 52 I-person
# Rebecca 59 66 B-person
# FlirtyNotes 5 16 B-person
# torture 28 35 B-corporation
# Melo 39 43 I-location
# Tiger 39 44 B-person
# Mama 45 49 I-person
# Sleeve 20 26 B-person
# Shop 27 31 I-person
# Mentally 20 28 B-person
# Brett 20 25 B-person
# Baier 26 31 I-person
# Fox 37 40 B-group
# News 41 45 I-group
# Judge 56 61 B-person
# Fox 91 94 B-group
# News 95 99 I-group
# WorldStarFunny 5 19 B-person
# Agreed 22 28 B-group
# monotone 36 44 B-corporation
# Alain 0 5 B-location
# Plague 18 24 B-group
# Evolved 31 38 B-person
# Curious 0 7 B-person
# George 8 14 I-person
# GOAT 29 33 B-location
# JacobSiSLife 5 17 B-person
# Kellyanne 13 22 B-location
# Conway 23 29 I-location
# EmmaWillis 61 71 B-location
# LessGovMoreFun 5 19 B-group
# White 62 67 B-location
# House 68 73 I-location
# Simple 0 6 B-group
# Strategy 7 15 I-corporation
# Concorde 27 35 B-location
# Calgary 41 48 B-location
# Europe 14 20 B-person
# Europe 23 29 B-person
# the 61 64 B-location
# White 65 70 B-location
# House 71 76 I-location
# Slater 86 92 I-group
# Jealous 84 91 B-person
# Yoshkumar 2 11 B-person
# Happens 12 19 I-person
# burrel 4 10 B-person
# Other 53 58 I-person
# João 59 63 I-location
# EJ 92 94 B-creative-work
# 3 95 96 I-creative-work
# Drebae 5 11 B-location
# C 76 77 I-creative-work
# GreaterThn 5 15 B-location
# LFDHcom 28 35 B-location
# Listen 36 42 I-location
# RichmondDoc 2 13 B-group
# Ioverthoughts 5 18 B-corporation
# XL 60 62 B-location
# LMAOOOO 43 50 B-location
# ✌ 73 74 B-group
# # ATCCfoodie 75 87 I-product
# Cousins 3 10 B-group
# Pelicans 23 31 B-corporation
# KenyeahMonae 2 14 B-person
# OP 125 127 B-group
# Digeridoo 25 34 B-person
# Sagna 54 59 B-location
# Обсуждение 0 10 B-corporation
# North 33 38 B-location
# Korea 39 44 I-location
# Lost 27 31 B-person
# RC 32 34 I-person
# plane 35 40 I-person
# Peter 17 22 B-creative-work
# Hitchens 23 31 I-group
# BLD 109 112 B-group
# Snickers 22 30 B-group
# Irish 163 168 B-group
# NHL 38 41 B-group
# OP 23 25 B-location
# Idee 37 41 B-person
# Rastus 23 29 B-location
# Edit 0 4 B-location
# CBC 29 32 B-group
# Marseille 26 35 B-location
# Many 20 24 B-creative-work
# Istanbul 38 46 B-location
# Velvet 0 6 I-product
# Srinagar 33 41 B-corporation
# Tomi 9 13 B-group
# Lahren 14 20 I-group
# Muslim 14 20 B-creative-work
# of 85 87 B-location
# Madrid 88 94 I-location
# REEEE 110 115 B-corporation
# the 15 18 B-location
# Stoke 19 24 I-location
# Calgary 12 19 B-location
# Swansea 70 77 B-location
# Bex 12 15 B-person
# Snickers 43 51 I-person
# Tom 7 10 B-person
# Andy 18 22 B-person
# Crystal 39 46 B-person
# Palace 47 53 I-person
# Crosspost 0 9 B-location
# Ca 0 2 B-location
# Stuff 23 28 B-group
# Jese 58 62 B-person
# Rodriguez 63 72 I-person
# Deulofeu 48 56 B-person
# Grimaldo 70 78 B-person
# Jürgen 2 8 B-group
# Klopp 9 14 I-product
# Multinational 33 46 I-location
# Gonçalo 47 54 B-group
# Guedes 55 61 I-group
# Shiba 10 15 B-group
# Peter 40 45 B-group
# Lim 46 49 I-person
# ZM 27 29 B-person
# Demolition 16 26 B-person
# Man 27 30 I-person
# SPLC 51 55 B-creative-work
# FIFA 17 21 B-group
# shitting 59 67 B-corporation
# Trump 19 24 B-person
# Waltengoo 54 63 B-location
# EDIT 0 4 B-location
# OP 71 73 B-location
# Edit 0 4 B-location
# Maronti 2 9 B-person
# Mirror 27 33 I-location
# HD 34 36 I-product
# HD 20 22 I-product
# 2002 255 259 B-location
# World 260 265 I-corporation
# Qatar 55 60 B-product
# 2022 61 65 I-product
# World 66 71 I-location
# Cup 72 75 I-location
# Trump 15 20 B-person
# Kelly 47 52 B-group
# Heh 0 3 B-person
# The 0 3 B-group
# OP 4 6 I-group
# jawans 47 53 B-location
# Siachen 81 88 B-person
# Glacier 89 96 I-person
# Obligatory 0 10 B-location
# karma 16 21 B-person
# Obligatory 0 10 B-location
# António 16 23 B-person
# Guterres 24 32 I-person
# UN 40 42 B-person
# folk 39 43 B-person
# Trump 82 87 B-person
# Siachen 33 40 B-location
# Mo-bot 15 21 B-location
# NAH 9 12 B-person
# NAAAHHH 13 20 I-person
# Trump 111 116 B-person
# Navy 5 9 B-person
# Yaletown 55 63 B-group
# The 0 3 B-creative-work
# Prem 4 8 B-person
# IMO 51 54 B-location
# Centrelink 19 29 B-product
# Edit 0 4 B-location
# Bingo 0 5 B-person
# Don 20 23 B-person
# Chuck 0 5 B-location
# BLM 39 42 B-corporation
# ' 0 1 I-creative-work
# Many 2 6 B-creative-work
# Istanbul 20 28 B-location
# Zealand 39 46 B-creative-work
# Internode 14 23 B-corporation
# Clippers 177 185 B-location
# Tottenham 29 38 B-location
# Chelsea 43 50 B-person
# shitting 74 82 B-corporation
# Giroud 86 92 B-person
# Trump 37 42 I-person
# Nazis 96 101 B-location
# Trump 107 112 B-person
# Twilight 16 24 B-location
# Zone 25 29 I-location
# Menge 176 181 B-person
# Bernie 17 23 B-person
# OP 53 55 B-location
# jay 104 107 B-person
# Trump 92 97 B-person
# Jesus 0 5 B-person
# Chelsea 0 7 B-person
# Ken 0 3 B-group
# Messi 30 35 B-person
# Adebayor 27 35 B-product
# Democrats 43 52 B-location
# Fake 120 124 B-group
# News 125 129 I-group
# membership 55 65 B-corporation
# Moore 101 106 B-location
# Park 107 111 I-location
# Dark 68 72 B-product
# Knight 73 79 I-creative-work
# Zlatan 21 27 B-location
# Lel 0 3 B-product
# Zealandia 77 86 B-location
# Sky 25 28 B-corporation
# MontansKittenSighs 5 23 B-person
# Trump 104 109 B-person
# Corbyn 29 35 B-location
# XI 152 154 B-group
# Europe 41 47 B-location
# Topic 102 107 B-location
# Coleman 25 32 B-product
# Aspects 39 46 B-creative-work
# Electric 16 24 B-corporation
# Kirchhoff 103 112 B-product
# Rogue 48 53 B-corporation
# One 54 57 I-creative-work
# Imperial 161 169 B-group
# Transcendent 39 51 B-creative-work
# Man 52 55 I-creative-work
# Which 0 5 B-person
# OP 192 194 B-location
# Homer 96 101 B-person
# Cuba 114 118 B-location
# Universal 53 62 B-creative-work
# Basic 63 68 I-creative-work
# Trump 16 21 B-creative-work
# physics 56 63 B-location
# Identify 0 8 B-group
# Doctor 24 30 B-location
# Gauge 17 22 I-product
# Thanku 10 16 B-person
# Thanku 65 71 B-person
# Gallifreyan 2 13 B-group
# Travel 7 13 B-corporation
# Ban 14 17 I-corporation
# Biometric 50 59 B-creative-work
# Entry- 60 66 I-creative-work
# Exit 67 71 I-product
# System 81 87 B-location
# Olive 9 14 B-corporation
# Emma 19 23 B-person
# Miss 46 50 B-product
# Peregrine 51 60 I-product
# Peculiar 74 82 B-person
# Children 83 91 I-person
# error 35 40 I-product
# Lee 59 62 B-person
# escape 57 63 B-creative-work
# Pokémon 35 42 I-person
# Parliament 28 38 B-location
# Parliament 78 88 B-location
# Server 0 6 B-person
# OpenSSH 21 28 B-location
# Dimensions 148 158 B-corporation
# galvanometer 81 93 I-product
# Garvan 3 9 B-person
# the 25 28 B-location
# Physics 29 36 I-location
# SE 37 39 I-location
# Meta 112 116 B-group
# Meta 278 282 B-group
# Java 0 4 B-group
# Object 5 11 I-group
# encryption 12 22 I-group
# Eastern 52 59 B-location
# Europe 60 66 I-location
# PublicKey 80 89 B-product
# Supreme 49 56 B-location
# Court 57 62 I-location
# nuisance 164 172 B-person
# Kessel 21 27 B-group
# Xantec 2 8 B-location
# Diagon 113 119 B-group
# Alley 120 125 I-person
# Hagrid 150 156 B-person
# Hagrid 274 280 B-person
# Harry 325 330 B-person
# DA 334 336 B-location
# KEINE 0 5 B-location
# Klein 134 139 I-person
# Monasch 225 232 B-location
# Vrĳzinnige 241 251 B-group
# paragraph 261 270 B-person
# Steeven 2 9 B-location
# OP 67 69 B-location
# Supposing 100 109 B-person
# Jina 25 29 B-person
# Hasbro 291 297 B-person
# Lexicon 432 439 B-group
# Carpetsmoker 2 14 B-group
# Eastern 47 54 B-location
# Western 76 83 B-location
# Europe 84 90 I-location
# Brythan 2 9 B-location
# Qmechanic 2 11 B-product
# Physics 62 69 B-location
# CPHPython 2 11 B-group
# Europe 16 22 B-person
# Thorin 8 14 B-corporation
# Arkenstone 85 95 B-person
# Trilarion 2 11 B-product
# Negative 12 20 I-person
# Torture 23 30 B-product
# torture 97 104 B-corporation
# torture 177 184 B-person
# Physics 11 18 B-location
# Jim 118 121 B-person
# the 223 226 B-location
# context 227 234 I-location
# Bordeaux 36 44 B-product
# the 3 6 B-location
# context 7 14 I-location
# FIDO 18 22 B-corporation
# the 5 8 I-creative-work
# Borg 9 13 I-creative-work
# Always 14 20 I-creative-work
# The 5 8 B-creative-work
# Six 9 12 I-creative-work
# Watson 36 42 B-group
# Sherlock 49 57 B-location
# Network 0 7 I-product
# Does 0 4 B-person
# bipedal 173 180 B-location
# Esp 74 77 B-person
# FG 90 92 B-location
# Shire 339 344 B-creative-work
# COYB 0 4 B-person
# server 16 22 B-person
# TOS 35 38 B-corporation
# Does 0 4 B-person
# PEM 36 39 B-product
# Cheeta 23 29 B-group
# Cheeta 35 41 B-group
# the 9 12 B-person
# President 13 22 I-person
# United 30 36 I-group
# States 37 43 I-location
# President 17 26 B-person
# Trump 27 32 I-person
# TOS 78 81 B-corporation
# * 82 83 I-product
# Animated 0 8 B-person
# Trump 27 32 B-person
# Access 0 6 B-group
# Control 7 14 I-group
# Primitives 15 25 I-group
# Which 0 5 B-person
# Sci- 6 10 I-person
# Fi 11 13 I-person
# Commutation 0 11 I-corporation
# Relation 12 20 I-corporation
# Dirac 33 38 B-person
# Hamiltonian 39 50 I-person
# Digimon 23 30 B-person
# Firstly 0 7 B-person
# R 8 9 I-person
# Recreation 33 43 B-location
# recreation 53 63 B-location
# Secondly 125 133 B-person
# Vietnam 229 236 B-location
# Gmail 30 35 B-corporation
# dreams 56 62 B-corporation
# Sci- Fi 31 38 B-product
# Paul 2 6 B-person
# Minas 53 58 B-group
# First 72 77 I-creative-work
# Lúthien 149 156 B-location
# Neville 23 30 B-location
# Neville 265 272 B-person
# Seamus 293 299 B-group
# Cool 71 75 B-group
# Trump ' 41 48 B-person
# Biased 0 6 B-person
# MetaCanadian 53 65 B-person
# error 113 118 B-product
# Authy 22 27 B-person
# Snape 14 19 B-product
# Horcrux 96 103 B-group
# Snowman 2 9 B-person
# Excellent 51 60 B-location
# Suggestions 0 11 B-group
# Windows 81 88 B-product
# Earth 69 74 B-creative-work
# King 24 28 B-location
# Arthur 29 35 I-location
# robot 90 95 I-corporation
# scepter 96 103 I-product
# Carrie 82 88 B-corporation
# However 99 106 B-person
# Most 168 172 B-group
# server 92 98 B-person
# MPS 2 5 B-group
# Ubuntu 35 41 B-person
# Batman 34 40 B-person
# Joker 59 64 B-location
# Donald 17 23 B-person
# Duck 24 28 I-person
# Meta 111 115 B-group
# Meta 212 216 B-group
# Glenn 42 47 B-person
# Greenwald 48 57 I-person
# Mandalorian 16 27 B-person
# Mandalorians designed 53 74 B-person
# GhostSec 63 71 B-person
# Comme 0 5 B-location
# Matrix 4 10 B-person
# Nebuchadnezzar 25 39 B-location
# Valorum 157 164 B-location
# Distribution 0 12 B-location
# Oblivion 40 48 B-group
# MatchThread 6 17 B-product
# OP 26 28 B-location
# server 54 60 B-product
# Understood 0 10 B-location
# Vulcan 59 65 B-product
# Donnager 13 21 B-person
# Democrats 22 31 B-location
# Trump 75 80 B-person
# President 50 59 I-person
# Valorum 2 9 B-location
# Potterwatch 11 22 B-creative-work
# R 61 62 I-creative-work
# Buffer 0 6 B-group
# Harry 41 46 B-person
# However 307 314 B-person
# Labs 25 29 B-location
# Skyview 32 39 B-group
# Observatory 40 51 I-group
# Smith 54 59 B-person
# Tower 60 65 I-person
# Observation 70 81 B-group
# Bank 53 57 B-person
# Negan 42 47 I-person
# Ca 0 2 B-location
# server 39 45 B-product
# TD 19 21 B-person
# President 8 17 I-person
# Court 45 50 B-group
# Obi- 24 28 B-corporation
# Tor 20 23 B-location
# Hidden 24 30 I-location
# Er 52 54 I-location
# Powerful 37 45 B-corporation
# tube 125 129 B-location
# Thomas 15 21 B-person
# Jane 22 26 I-person
# Expanse 56 63 I-group
# Collide 66 73 B-location
# Parliament 8 18 B-location
# emphasis 79 87 B-person
# the 14 17 I-creative-work
# Beast 18 23 I-creative-work
# kill 24 28 I-person
# Julia 29 34 B-person
# Born- 40 45 B-group
# Infeld 46 52 I-group
# Michigan 56 64 B-person
# Zaphod 47 53 B-group
# Beeblebrox 54 64 I-group
# Isabella 37 45 B-group
# El 13 15 B-location
# English 21 28 B-group
# Middle 40 46 B-location
# OP 31 33 B-location
# Demi 2 6 B-person
# * Arrangements 7 21 B-person
# Defence 143 150 B-person
# Spokesman 151 160 I-person
# Colonel 161 168 I-person
# Kalia 176 181 B-location
# Becky 0 5 B-corporation
# Snickers 11 19 B-group
# Gordon 2 8 B-location
# Not 9 12 I-location
# Higgs 77 82 I-group
# Demiguise 111 120 B-person
# Cloak 206 211 B-location
# Miss 230 234 B-product
# Granger 235 242 I-product
# Demiguise 288 297 B-corporation
# paragraph 332 341 B-person
# server 23 29 B-product
# input 38 43 B-location
# Generally 229 238 B-person
# Clinton 8 15 B-group
# DonatelloSwansino 2 19 B-location
# Kirk 181 185 B-person
# Windows 26 33 B-product
# Hello 34 39 I-corporation
# Windows 75 82 B-product
# the 4 7 B-group
# Martians 8 16 I-group
# Ack 36 39 B-person
# Democrats 32 41 B-location
# Lelouch 25 32 B-person
# teen 9 13 B-person
# Auckland 71 79 B-person
# Legality 8 16 B-location
# Citizens 39 47 B-product
# Checked 48 55 I-product
# UN 20 22 B-person
# UN 31 33 B-person
# Bank 68 72 I-corporation
# Javier 0 6 B-corporation
# Assassins 36 45 B-group
# Creed 46 51 I-group
# CandiedOrange 2 15 B-location
# molecules 76 85 B-location
# Ireland 123 130 B-location
# CP 42 44 B-location
# C- 63 65 B-person
# CP 81 83 B-location
# Comments 0 8 B-corporation
# XiongChiamiov 2 15 B-corporation
# input 121 126 B-person
# The 57 60 B-location
# Next 61 65 I-creative-work
# Three 66 71 I-creative-work
# Days 72 76 I-group
# Higgs 0 5 B-group
# However 123 130 B-person
# ^ 362 363 B-location
# Super 42 47 B-corporation
# Yautja 48 54 I-corporation
# TOS 15 18 I-product
# Discovery 69 78 B-location
# potential 9 18 B-person
# Identify 0 8 B-group
# Grimaldo 11 19 B-person
# Highschool 11 21 B-group
# Fedxa 102 107 B-location
# Does 0 4 B-product
# Rogue 5 10 I-product
# Hyperspace 59 69 B-group
# Radio 70 75 I-group
# Books 0 5 B-group
# itpastorn 2 11 B-corporation
# Wildcard 2 10 B-group
# Bsc 150 153 B-person
# + 154 155 I-product
# MsC 156 159 I-product
# Minkowski 14 23 I-creative-work
# Concerns 41 49 B-location
# Rotations 61 70 I-location
# Gallifreyan 2 13 B-location
# Boro 28 32 B-corporation
# Krumia 2 8 B-location
# Asimov 25 31 B-person
# KeePass 27 34 I-location
# Cracker 35 42 I-location
# Italian 30 37 B-product
# Italian 84 91 B-product
# English 182 189 B-group
# the 42 45 B-location
# Dark 46 50 I-location
# Side 51 55 I-location
# jpmc 2 6 B-person
# Naval 256 261 B-group
# maintenance 392 403 B-location
# Dynkin 18 24 I-product
# diagrams 25 33 I-product
# Wookipedia 29 39 B-location
# George 4 10 B-person
# Smiley 11 17 I-person
# Bill 49 53 B-location
# Haydon 54 60 I-location
# European 12 20 B-location
# Union 21 26 I-location
# General 39 46 B-group
# Data 47 51 I-group
# Protection 52 62 I-product
# Regulation 63 73 I-product
# Vinny 233 238 B-location
# Europe 49 55 B-location
# EM 37 39 B-person
# Potential 0 9 B-person
# HTTP 10 14 I-person
# Greens 0 6 B-corporation
# Statistial 47 57 B-location
# Physics 58 65 I-location
# SQB 2 5 B-location
# M 107 108 B-person
# However 164 171 B-person
# Powerless 27 36 B-location
# James 36 41 B-person
# Potter 42 48 I-person
# Gurez 33 38 B-location
# Cheney 0 6 B-corporation
# Quidditch 16 25 B-corporation
# PC 178 180 B-group
# buttocks 28 36 B-location
# YungBang 9 17 B-product
# 954 18 21 I-product
# Yakuza 11 17 B-group
# Trey 79 83 B-person
# Gowdy 84 89 I-person
# Jason 94 99 B-person
# Chaffetz 100 108 I-person
# The 57 60 B-group
# The 79 82 B-creative-work
# World 83 88 I-creative-work
# StrauberryJam 18 31 B-product
# Children 0 8 B-person
# Audiologist 30 41 B-location
# BIRMINGHAM 56 66 B-person
# Apply 67 72 I-person
# NLWastedLink 19 31 B-corporation
# iCleverOfficial 5 20 B-location
# # Giveaway 23 33 B-group
# iClever 114 121 B-product
# teen 29 33 B-person
# Celebrate 0 9 B-creative-work
# Burns 10 15 B-person
# Night 16 21 I-person
# the 27 30 B-person
# Bobby 31 36 I-person
# Burns 37 42 I-person
# https://t.co/YPSuF6GgVm 53 76 B-location
# Assistant 6 15 B-person
# Location 16 24 I-person
# Angeles 31 38 B-group
# OMB 0 3 B-location
# Mulvaney 17 25 I-person
# Medicare 61 69 B-location
# WSJ 100 103 B-product
# incanted 50 58 B-corporation
# Gwynstone 5 14 B-corporation
# Rachel 14 20 B-person
# Ubermatik 2 11 B-location
# Anti 12 16 I-location
# 👌 56 57 B-corporation
# jellombooty 5 16 B-location
# CarolSankar 5 16 B-location
# # Equalpay 57 67 B-location
# Don 0 3 B-person
# tea 16 19 B-product
# MM 25 27 B-person
# Prompto 32 39 B-location
# Daily 0 5 B-corporation
# Audio 6 11 I-corporation
# Bible 12 17 I-location
# FANGIRLOVERLOAD 2 17 B-location
# 😄 27 28 B-location
# DESERVE 86 93 B-group
# Cardio 10 16 B-location
# Kickboxing 17 27 I-location
# Equipment 71 80 B-creative-work
# Resources 25 34 B-person
# Love 0 4 B-group
# Lynda 5 10 I-product
# AlicesdrThe 2 13 B-creative-work
# KKKKKKKKKK 29 39 B-group
# BeautyOfAnAries 5 20 B-corporation
# Bots 23 27 B-person
# MissMcCleary 5 17 B-location
# Doctor 31 37 B-location
# Mediaite 5 13 B-location
# Minnesota 16 25 B-group
# Prostate 72 80 B-corporation
# Cancer 81 87 I-corporation
# Redditor 21 29 B-location
# Calgary 48 55 B-location
# Roulette 22 30 B-location
# Margarita 57 66 B-person
# Madness 67 74 I-person
# Shrimp 93 99 B-group
# BadlandsNPS 5 16 B-corporation
# KA 33 35 B-location
# Honestly 52 60 B-person
# KidDirtyJokes 5 18 B-location
# Bmac 2 6 B-location
# BiasedGirl 14 24 B-corporation
# jimgeraghty 27 38 B-person
# Brit 25 29 B-creative-work
# elessar 5 12 B-location
# Psst 18 22 B-person
# Don 106 109 B-person
# Bulls 2 7 B-corporation
# 👏 88 89 B-creative-work
# Harry 5 10 B-person
# Styles 13 19 B-location
# Glasgow 22 29 B-location
# Google 12 18 B-product
# Nazis 75 80 B-location
# Pain 23 27 B-person
# Land 21 25 B-group
# Smiles - 29 37 B-product
# Trump 14 19 B-person
# Badlands 18 26 B-location
# National 27 35 I-location
# Park 36 40 I-location
# Trump 84 89 I-person
# Kembar 22 28 B-group
# Mas 29 32 I-group
# Utara 33 38 I-product
# - 39 40 I-product
# Court Reinstates 0 16 B-product
# Acne 47 51 B-location
# Source 2 8 B-location
# Gurez 50 55 B-location
# Marengo 76 83 B-product
# Ireland 87 94 B-location
# Florence 31 39 B-person
# KnifingTourney 5 19 B-location
# Judges 47 53 B-person
# Someone 0 7 B-person
# DumpTrump 5 14 B-product
# Sensor 39 45 B-location
# Sensor 91 97 B-location
# Sensor 143 149 B-location
# Air 18 21 B-product
# Jordan 22 28 I-product
# 11 29 31 I-product
# XI 32 34 I-product
# # Retro 35 42 I-product
# Cherry 47 53 B-person
# Igbtryden 5 14 B-person
# Mega 75 79 B-group
# JennaJackson 2 14 B-group
# DeadstockUtopia 45 60 B-location
# Sacha 0 5 B-person
# Baron 6 11 I-person
# Cohen 12 17 I-person
# The 49 52 B-group
# Brothers 53 61 I-group
# # SachaBaronCohen 68 85 B-group
# Aquarius 77 85 B-group
# CVG 80 83 B-location
# WhennBoys 5 14 B-group
# PornHardd 5 14 B-location
# Teddys 31 37 B-location
# Chicas 67 73 B-person
# VirtuAss 82 90 B-location
# PornHardd 118 127 B-location
# River 44 49 I-product
# Arri 23 27 B-person
# Fisher- 63 70 I-creative-work
# P 71 72 I-creative-work
# # naked 0 7 B-group
# teen 21 25 B-person
# resolve 42 49 B-person
# Good 36 40 B-location
# Morning 41 48 I-location
# Britain 49 56 I-location
# Won 101 104 B-person
# jellibun 2 10 B-location
# 👊 82 83 B-person
# Darius 7 13 B-person
# # DumpTrump 68 79 B-group
# HamillHimself 126 139 B-location
# BadlandsNPS 17 28 B-corporation
# # TrumpLeaks 85 97 B-creative-work
# “ 0 1 B-location
# La 2 4 B-location
# La 5 7 I-location
# Land 8 12 I-location
# Academy 27 34 B-person
# Award 35 40 I-person
# tying 55 60 B-corporation
# Zlatan 31 37 B-location
# Amy 27 30 B-person
# Winehouse 31 40 I-person
# Listen 54 60 B-location
# Clean 0 5 B-group
# Sweep 6 11 I-group
# mexico 107 113 B-location
# Trump 62 67 B-person
# Illuminatiam 0 12 B-person
# First 19 24 I-creative-work
# Testament 25 34 I-creative-work
# Of 35 37 I-creative-work
# The 38 41 I-creative-work
# Illuminati 42 52 I-corporation
# PrisonPlanet 5 17 B-location
# Angels 56 62 I-corporation
# Snatam 79 85 B-person
# Kaur 86 90 I-person
# Suṉi 97 101 I-creative-work
# LCGila 2 8 B-location
# Clark 11 16 B-person
# https://t.co/WS4mEwtgnw 44 67 I-product
# White 53 58 B-location
# House 59 64 I-location
# Leaves 0 6 B-person
# nochillthalia 5 18 B-person
# JiovanniVargas 2 16 B-person
# Moana 19 24 B-location
# # Smule 50 57 B-group
# Literally 23 32 B-person
# Incheon 7 14 B-person
# South 17 22 B-corporation
# Korea 23 28 I-product
# : 29 30 I-product
# Old 31 34 B-group
# Meets 35 40 I-location
# MartinBelam 5 16 B-person
# IngrahamAngle 5 18 B-product
# MaryKayCabot 2 14 B-group
# LUB expires 0 11 B-product
# Tamara 12 18 B-person
# Lovett 19 25 I-person
# negligence 45 55 B-person
# BeatrizDjee 2 13 B-group
# MAAX 14 18 I-group
# FillWerrell 5 16 B-location
# wvucobe 5 12 B-location
# CoachHuggs 30 40 B-location
# Don 66 69 B-person
# s 86 87 I-product
# Gold 88 92 B-product
# Rush 93 97 I-product
# Source 2 8 B-location
# Lance 2 7 B-group
# prank 24 29 B-person
# M 144 145 B-person
# & amp ; 146 153 I-creative-work
# BadlandsNPS 26 37 B-corporation
# Golden 97 103 B-location
# Eagle 104 109 I-location
# korin 13 18 B-corporation
# Don 20 23 B-person
# TI 71 73 B-group
# Rubberband 78 88 B-location
# Don 0 3 B-person
# Hypnosis 30 38 B-corporation
# LOVE 59 63 B-group
# PREMIERE 64 72 I-group
# Lowongan 0 8 B-person
# PT 9 11 I-person
# Indonesia 21 30 I-person
# Graduate 54 62 B-product
# Management 63 73 I-location
# Citilink 82 90 B-person
# MatsMats 5 13 B-person
# NatalieGBorden 35 49 B-location
# rope 14 18 B-person
# karibrownnn 5 16 B-person
# Don 14 17 B-person
# If 25 27 B-creative-work
# DELL 0 4 B-person
# Inspiron 5 13 I-person
# Laptop 79 85 B-product
# PrisonPlanet 5 17 B-location
# Kellyanne 120 129 B-location
# Ziploc 78 84 B-corporation
# Bellerin 8 16 B-corporation
# CNNPolitics 2 13 B-location
# VroniquePersic 2 16 B-product
# 1 17 18 I-creative-work
# serina 31 37 B-product
# Marujk 93 99 B-location
# DonnieWahlberg 123 137 B-product
# UG 0 2 B-group
# Respect 18 25 B-person
# Business 32 40 B-corporation
# Advertise 73 82 B-person
# Anything 83 91 I-person
# ICYMI- 14 20 B-group
# Lee 21 24 I-location
# Joon 25 29 I-location
# Of 63 65 I-creative-work
# The 66 69 I-creative-work
# Actor 70 75 I-group
# Dating 76 82 I-group
# HugotDre 5 13 B-location
# Serbia 37 43 B-person
# Jak 139 142 B-person
# The 21 24 B-creative-work
# Black 25 30 I-creative-work
# Keys 31 35 I-creative-work
# Lonely 40 46 B-creative-work
# Boy 47 50 I-group
# The 25 28 I-group
# Perfect 29 36 I-group
# Outreach 37 45 I-creative-work
# quora 76 81 B-product
# Linux 48 53 B-person
# Don 18 21 B-person
# jzaffos 5 12 B-group
# Confidential 114 126 B-group
# Tom 4 7 B-person
# Don 0 3 B-person
# teen 9 13 B-person
# GayPrideBelize 5 19 B-location
# Belize 57 63 B-creative-work
# BiggDawg 38 46 B-creative-work
# C 47 48 I-creative-work
# Loc 49 52 I-creative-work
# DamnFeelings 5 17 B-location
# KleinISD 5 13 B-location
# KleinISD 22 30 B-location
# Daily 31 36 I-location
# KISD 84 88 B-location
# _ 89 90 I-person
# DoctorZen 5 14 B-person
# EPA 140 143 B-location
# VicMensa 5 13 B-location
# LegalGeagle 2 13 B-product
# Cheney 64 70 B-corporation
# KATHERllNE 2 12 B-location
# Adulthood 17 26 B-group
# NapaRegister 74 86 B-group
# NapaPD 89 95 B-location
# Andrew 69 75 B-creative-work
# Little 76 82 I-creative-work
# Cloyd 58 63 B-person
# Rivers 64 70 I-person
# 000 53 56 B-person
# Warren 108 114 I-person
# Marcusb 2 9 B-person
# RichHomieHuang 16 30 B-corporation
# X-Files started 55 70 B-person
# Museum 34 40 I-corporation
# United 38 44 I-group
# States 45 51 I-location
# Selamat 0 7 B-person
# BDSM 42 46 B-group
# # BOSSTIPS 91 101 B-group
# M 35 36 B-person
# # organicallygrown 35 53 B-group
# Chiquita 56 64 B-person

# %% [markdown]
# ELMo (EMBEDDING FROM LANGUAGE MDEL)

# %% [markdown]
# STEP:1 LOADING TRAIN DATA & DOING BASIC PRE-PROCESSING AFTER COMPLETING EDA

# %%
df = pd.read_csv('train.txt', sep = '\t', header = None, quoting=csv.QUOTE_NONE, skip_blank_lines = False)
df['Sentence #'] = ''
i = 1
for ind in df.index-1:
    if type(df.iloc[ind,0])==float:
        i = i+1
        df.iloc[ind+1,2] = 'Sentence: ' + str(i)
    df.iloc[ind,2] = 'Sentence: ' + str(i)
df = df.dropna()

# %%
df
# Out:
#                0  1      Sentence #
# 0      @paulwalk  O     Sentence: 2
# 1             It  O     Sentence: 2
# 2             's  O     Sentence: 2
# 3            the  O     Sentence: 2
# 4           view  O     Sentence: 2
# ...          ... ..             ...
# 66118         39  O  Sentence: 3400
# 66119   GMT+0000  O  Sentence: 3400
# 66120          (  O  Sentence: 3400
# 66121        UTC  O  Sentence: 3400
# 66122          )  O  Sentence: 3400
#
# [62725 rows x 3 columns]

# %%
agg_func = lambda s: [[w,t] for w,t in zip(s[0],s[1])]

# %%
grouped = df.groupby("Sentence #").apply(agg_func)

# %%
print(len(grouped))
# Out:
# 3397

# %%
tags = list(set(df[1].values))
n_tags = len(tags)

# %%
largest_sen = max(len(sen) for sen in grouped)
print('biggest sentence has {} words'.format(largest_sen))
# Out:
# biggest sentence has 41 words

# %% [markdown]
# STEP:1.1 PADDING EACH SENTENCE AND TAGS TO MAKE THEM UNIFORMLY SIZED

# %%
max_len = 41
X = [[w[0]for w in s] for s in grouped]
new_X = []
for seq in X:
    new_seq = []
    for i in range(max_len):
        try:
            new_seq.append(seq[i])
        except:
            new_seq.append("PADword")
    new_X.append(new_seq)
print(new_X[22])
# Out:
# ['OH-OH', 'It', 'seems', 'Lindsay', 'Lohan', 'maybe', 'be', 'heading', 'back', 'to', 'jail', '.', 'The', 'actress', 'has', 'failed', 'a', 'court', 'mandated', 'drug', 'test', '&amp;', 'could', 'face', '30', 'days', 'in', 'prison', 'PADword', 'PADword', 'PADword', 'PADword', 'PADword', 'PADword', 'PADword', 'PADword', 'PADword', 'PADword', 'PADword', 'PADword', 'PADword']

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
tags2index = {t:i for i,t in enumerate(tags)}
y = [[tags2index[w[1]] for w in s] for s in grouped]
y = pad_sequences(maxlen=max_len, sequences=y, padding="post", value=tags2index["O"])
y[22]
# Out:
# array([ 2,  2,  2, 10,  7,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#         2,  2,  2,  2,  2,  2,  2])

# %% [markdown]
# STEP:2 SPLITTING THE DATA INTO TRAINING TESTING AND VALIDATION SET

# %%
from sklearn.model_selection import train_test_split

X_tr, X_te, y_tr, y_te = train_test_split(new_X, y, test_size=0.1, random_state=2018)

# %% [markdown]
# STEP:3 DOWNLOADING THE ORIGINAL MODEL, INITIALIZING THE VARIABLES, CONVERTING THE PRE-PROCESSED DATA INTO TENSORS, ADDING NEW LAYERS TO MODEL & RUNNING THE MODEL

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import tensorflow_hub as hub

sess = tf.Session()
tf.compat.v1.keras.backend.set_session(sess)
elmo_model = hub.Module("https://tfhub.dev/google/elmo/3", trainable=True)
sess.run(tf.global_variables_initializer())
sess.run(tf.tables_initializer())
# Out:
# WARNING:tensorflow:From c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
batch_size = 32
def ElmoEmbedding(x):
    return elmo_model(inputs={"tokens": tf.squeeze(tf.cast(x,tf.string)),"sequence_len": tf.constant(batch_size*[max_len])
                     },
                      signature="tokens",
                      as_dict=True)["elmo"]

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional, Lambda, Input, add

input_text = Input(shape=(max_len,), dtype=tf.string)
embedding = Lambda(ElmoEmbedding, output_shape=(max_len, 1024))(input_text)
x = Bidirectional(LSTM(units=512, return_sequences=True,
                       recurrent_dropout=0.2, dropout=0.2))(embedding)
x_rnn = Bidirectional(LSTM(units=512, return_sequences=True,
                           recurrent_dropout=0.2, dropout=0.2))(x)
x = add([x, x_rnn])  # residual connection to the first biLSTM
out = TimeDistributed(Dense(n_tags, activation="softmax"))(x)
model = Model(input_text, out)
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# WARNING:tensorflow:From c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
batch_size = 32
X_tr, X_val = X_tr[:75*batch_size], X_tr[-20*batch_size:]
y_tr, y_val = y_tr[:75*batch_size], y_tr[-20*batch_size:]
y_tr = y_tr.reshape(y_tr.shape[0], y_tr.shape[1], 1)
y_val = y_val.reshape(y_val.shape[0], y_val.shape[1], 1)

# %%
history = model.fit(np.array(X_tr), y_tr, validation_data=(np.array(X_val), y_val),batch_size=batch_size, epochs=3, verbose=1)
# Out:
# Train on 2400 samples, validate on 640 samples
# Epoch 1/3
# 2400/2400 [==============================] - ETA: 0s - loss: 0.1030 - acc: 0.9790
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\keras\engine\training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 2400/2400 [==============================] - 1292s 538ms/sample - loss: 0.1030 - acc: 0.9790 - val_loss: 0.0619 - val_acc: 0.9853
# Epoch 2/3
# 2400/2400 [==============================] - 1341s 559ms/sample - loss: 0.0596 - acc: 0.9846 - val_loss: 0.0499 - val_acc: 0.9873
# Epoch 3/3
# 2400/2400 [==============================] - 1406s 586ms/sample - loss: 0.0467 - acc: 0.9871 - val_loss: 0.0487 - val_acc: 0.9872

# %% [markdown]
# STEP 4: TESTING THE MODEL

# %%
len(X_te[300])
# Out:
# 41

# %%
from seqeval.metrics import precision_score, recall_score, f1_score, classification_report
X_test = X_te[:10*batch_size]
test_pred = model.predict(np.array(X_test), verbose=1)

# %% [markdown]
# STEP 4.1: CONVERTING THE PREDICTED VALUES BACK TO LABELS & CALCULATING THE METRICS

# %%
idx2tag = {i: w for w, i in tags2index.items()}

def pred2label(pred):
    out = []
    for pred_i in pred:
        out_i = []
        for p in pred_i:
            p_i = np.argmax(p)
            out_i.append(idx2tag[p_i].replace("PADword", "O"))
        out.append(out_i)
    return out
def test2label(pred):
    out = []
    for pred_i in pred:
        out_i = []
        for p in pred_i:
            out_i.append(idx2tag[p].replace("PADword", "O"))
        out.append(out_i)
    return out
    
pred_labels = pred2label(test_pred)
test_labels = test2label(y_te[:10*32])
print(classification_report(test_labels, pred_labels))
# Out:
#                precision    recall  f1-score   support
#
#   corporation       0.38      0.33      0.36        15
# creative-work       0.43      0.23      0.30        13
#         group       0.50      0.20      0.29        35
#      location       0.63      0.44      0.52        54
#        person       0.74      0.63      0.68        51
#       product       0.33      0.33      0.33        12
#
#     micro avg       0.59      0.42      0.49       180
#     macro avg       0.50      0.36      0.41       180
#  weighted avg       0.58      0.42      0.48       180

# %% [markdown]
# STEP 5: TESTING ON UNSEEN DATA (TEST.TXT)

# %% [markdown]
# STEP 5.1: LOADING AND PRE-PROCESSING TEST DATA

# %%
df1 = pd.read_csv('test.txt', sep=' ', quoting=csv.QUOTE_NONE, skip_blank_lines = False, header=None)
df1['Sentence #'] = ''
i = 0
for ind in df1.index-1:
    if type(df1.iloc[ind,0])==float:
        i = i+1
        df1.iloc[ind+1,1] = 'Sentence: ' + str(i)
    df1.iloc[ind,1] = 'Sentence: ' + str(i)
df1 = df1.dropna()

# %%
agg_func = lambda s: [ w for w in s[0]]
TEST_DATA = df1.groupby("Sentence #").apply(agg_func)

# %%
t_pred = model.predict(np.array(X_te[300:332]), verbose=1)
p_labels = pred2label(t_pred)

# %%
max_len = 41
X = TEST_DATA
new_TEST_X = []
for seq in X:
    new_seq = []
    for i in range(max_len):
        try:
            new_seq.append(seq[i])
        except:
            new_seq.append("PADword")
    new_TEST_X.append(new_seq)

# %%
i = 180 #TAKES TO THE 180TH SENTENCE 
p = model.predict(np.array(new_TEST_X[i:i+32]))[0] #TO CALCULATE PREDICTIONS FOR 32 MORE SENTENCES 
p = np.argmax(p, axis=-1)
print("{:15} {:5}: ({})".format("Word", "Pred", "True"))
print("="*30)
for w, true, pred in zip(X_te[i], y_te[i], p):
    if w != "__PAD__":
        print("{:15}:{:5} ({})".format(w, tags[pred], tags[true]))
# Out:
# Word            Pred : (True)
# ==============================
# @CHAMBERSfever :O     (O)
# i              :O     (O)
# used           :O     (O)
# to             :O     (O)
# have           :O     (O)
# fishes         :O     (O)
# but            :O     (O)
# they           :O     (O)
# lived          :O     (O)
# like           :O     (O)
# 5              :O     (O)
# days           :O     (O)
# what           :O     (O)
# pet            :O     (O)
# would          :O     (O)
# you            :O     (O)
# like           :O     (O)
# to             :O     (O)
# have           :O     (O)
# ?              :O     (O)
# i'm            :O     (O)
# deeply         :O     (O)
# in             :O     (O)
# love           :O     (O)
# with           :O     (O)
# Eli            :O     (B-person)
# PADword        :O     (O)
# PADword        :O     (O)
# PADword        :O     (O)
# PADword        :O     (O)
# PADword        :O     (O)
# PADword        :O     (O)
# PADword        :O     (O)
# PADword        :O     (O)
# PADword        :O     (O)
# PADword        :O     (O)
# PADword        :O     (O)
# PADword        :O     (O)
# PADword        :O     (O)
# PADword        :O     (O)
# PADword        :O     (O)
